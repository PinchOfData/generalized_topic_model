# %%
import pandas as pd
df = pd.read_csv('../data/us_politicians.csv')
df.dropna(subset=['doc_clean'], inplace=True)

import numpy as np
df['random'] = np.random.normal(size = len(df.index))

train = df.sample(frac=0.9,random_state=42)
test = df.drop(train.index).reset_index(drop=True)
train = train.reset_index(drop=True)

# %%
import sys
sys.path.append('../gtm/')
from corpus import GTMCorpus
from gtm import GTM
from sklearn.feature_extraction.text import CountVectorizer

# ---- 1. Fit vectorizer on training set ----
vectorizer = CountVectorizer(max_features=13000)  
vectorizer.fit(train["doc_clean"])

# ---- 2. Define modalities using this vectorizer ----
modalities = {
    "default": {
        "column": "doc_clean",
        "views": {
            "bow": {
                "type": "bow",
                "vectorizer": vectorizer
            }
        }
    }
}

# ---- 3. Create GTMCorpus datasets ----
train_dataset = GTMCorpus(
    train,
    modalities=modalities,
    labels="~random-1",
    content="~1"
)

test_dataset = GTMCorpus(
    test,
    modalities=modalities,  
    labels="~random-1",
    content="~1"
)

# %%
# Train the model
tm = GTM(
    train_dataset, 
    test_dataset,
    n_topics=20,
    predictor_type='regressor', # 'regressor' for continuous variables such as GDP,
    w_pred_loss=1
)
# Out:
# Epoch   1	Mean Training Loss:12.0643077
#
# Topic_0: ['good', 'less', 'information', 'state', 'fear', 'figure', 'address', 'oppose']
# Topic_1: ['subcommittee', 'delay', 'describe', 'interested', 'policy', 'participate', 'majority', 'consider']
# Topic_2: ['money', 'turn', 'most', 'investment', 'aware', 'security', 'relief', 'vast']
# Topic_3: ['regard', 'resolution', 'immediate', 'emergency', 'seem', 'close', 'large', 'person']
# Topic_4: ['statement', 'particular', 'attempt', 'produce', 'testimony', 'give', 'value', 'majority_leader']
# Topic_5: ['accord', 'find', 'late', 'apply', 'maintenance', 'damage', 'oppose', 'revenue']
# Topic_6: ['next', 'requirement', 'decision', 'agency', 'particular', 'information', 'approach', 'dispose']
# Topic_7: ['thank', 'know', 'colleague', 'preserve', 'interested', 'institution', 'money', 'good']
# Topic_8: ['general', 'condition', 'program', 'station', 'decision', 'many', 'product', 'appropriate']
# Topic_9: ['great', 'point', 'capital', 'propose', 'avoid', 'weapon', 'energy', 'rest']
# Topic_10: ['free', 'republican', 'accomplish', 'dollar', 'cover', 'formal', 'urge', 'children']
# Topic_11: ['opportunity', 'let', 'third', 'argument', 'policy', 'account', 'direction', 'poor']
# Topic_12: ['full', 'wait', 'start', 'assume', 'subcommittee', 'measure', 'choice', 'improve']
# Topic_13: ['consideration', 'citizen', 'spend', 'pay', 'personnel', 'outstanding', 'clear', 'hand']
# Topic_14: ['moment', 'work', 'action', 'intent', 'product', 'detail', 'strike', 'propose']
# Topic_15: ['chairman', 'child', 'true', 'friend', 'legislation', 'prepare', 'nation', 'apply']
# Topic_16: ['reach', 'risk', 'hold', 'determine', 'history', 'status', 'entitle', 'present']
# Topic_17: ['condition', 'principal', 'emergency', 'requirement', 'clerk', 'month', 'request', 'lead']
# Topic_18: ['build', 'year', 'provision', 'promote', 'advise', 'come', 'executive', 'trouble']
# Topic_19: ['new', 'project', 'include', 'determine', 'major', 'justice', 'fight', 'important']
#
# Intercept: ['describe', 'transportation', 'fiscal', 'adopt', 'meet', 'nuclear', 'group', 'help']
#
#
# Epoch   1	Mean Validation Loss:11.7871985
#
# Topic_0: ['good', 'less', 'information', 'state', 'fear', 'figure', 'address', 'oppose']
# Topic_1: ['subcommittee', 'delay', 'describe', 'interested', 'policy', 'participate', 'majority', 'consider']
# Topic_2: ['money', 'turn', 'most', 'investment', 'aware', 'security', 'relief', 'vast']
# Topic_3: ['regard', 'resolution', 'immediate', 'emergency', 'seem', 'close', 'large', 'person']
# Topic_4: ['statement', 'particular', 'attempt', 'produce', 'testimony', 'give', 'value', 'majority_leader']
# Topic_5: ['accord', 'find', 'late', 'apply', 'maintenance', 'damage', 'oppose', 'revenue']
# Topic_6: ['next', 'requirement', 'decision', 'agency', 'particular', 'information', 'approach', 'dispose']
# Topic_7: ['thank', 'know', 'colleague', 'preserve', 'interested', 'institution', 'money', 'good']
# Topic_8: ['general', 'condition', 'program', 'station', 'decision', 'many', 'product', 'appropriate']
# Topic_9: ['great', 'point', 'capital', 'propose', 'avoid', 'weapon', 'energy', 'rest']
# Topic_10: ['free', 'republican', 'accomplish', 'dollar', 'cover', 'formal', 'urge', 'children']
# Topic_11: ['opportunity', 'let', 'third', 'argument', 'policy', 'account', 'direction', 'poor']
# Topic_12: ['full', 'wait', 'start', 'assume', 'subcommittee', 'measure', 'choice', 'improve']
# Topic_13: ['consideration', 'citizen', 'spend', 'pay', 'personnel', 'outstanding', 'clear', 'hand']
# Topic_14: ['moment', 'work', 'action', 'intent', 'product', 'detail', 'strike', 'propose']
# Topic_15: ['chairman', 'child', 'true', 'friend', 'legislation', 'prepare', 'nation', 'apply']
# Topic_16: ['reach', 'risk', 'hold', 'determine', 'history', 'status', 'entitle', 'present']
# Topic_17: ['condition', 'principal', 'emergency', 'requirement', 'clerk', 'month', 'request', 'lead']
# Topic_18: ['build', 'year', 'provision', 'promote', 'advise', 'come', 'executive', 'trouble']
# Topic_19: ['new', 'project', 'include', 'determine', 'major', 'justice', 'fight', 'important']
#
# Intercept: ['describe', 'transportation', 'fiscal', 'adopt', 'meet', 'nuclear', 'group', 'help']
#
#
# Epoch   2	Mean Training Loss:11.5033221
#
# Topic_0: ['good', 'less', 'state', 'information', 'address', 'oppose', 'fear', 'figure']
# Topic_1: ['subcommittee', 'interested', 'delay', 'policy', 'consider', 'describe', 'majority', 'attention']
# Topic_2: ['money', 'turn', 'most', 'investment', 'security', 'aware', 'authority', 'lie']
# Topic_3: ['regard', 'resolution', 'immediate', 'seem', 'large', 'introduce', 'person', 'close']
# Topic_4: ['statement', 'particular', 'attempt', 'give', 'testimony', 'value', 'produce', 'think']
# Topic_5: ['accord', 'find', 'apply', 'yield', 'late', 'oppose', 'place', 'revenue']
# Topic_6: ['next', 'requirement', 'decision', 'agency', 'particular', 'little', 'word', 'information']
# Topic_7: ['thank', 'know', 'colleague', 'preserve', 'money', 'institution', 'interested', 'good']
# Topic_8: ['general', 'many', 'condition', 'contribution', 'product', 'senator', 'program', 'appropriate']
# Topic_9: ['great', 'point', 'propose', 'capital', 'proposal', 'weapon', 'avoid', 'rest']
# Topic_10: ['free', 'republican', 'accomplish', 'dollar', 'cover', 'urge', 'rise', 'capital']
# Topic_11: ['let', 'opportunity', 'policy', 'third', 'account', 'argument', 'project', 'direction']
# Topic_12: ['full', 'wait', 'start', 'choice', 'subcommittee', 'assume', 'measure', 'hear']
# Topic_13: ['consideration', 'citizen', 'spend', 'pay', 'personnel', 'clear', 'appropriation', 'hand']
# Topic_14: ['work', 'moment', 'action', 'product', 'propose', 'intent', 'strike', 'base']
# Topic_15: ['chairman', 'friend', 'legislation', 'true', 'child', 'apply', 'prepare', 'nation']
# Topic_16: ['reach', 'hold', 'present', 'risk', 'history', 'determine', 'work', 'status']
# Topic_17: ['condition', 'request', 'principal', 'requirement', 'month', 'send', 'clerk', 'emergency']
# Topic_18: ['build', 'year', 'provision', 'matter', 'promote', 'advise', 'come', 'move']
# Topic_19: ['new', 'project', 'include', 'determine', 'justice', 'important', 'major', 'affect']
#
# Intercept: ['describe', 'fiscal', 'adopt', 'meet', 'help', 'good', 'transportation', 'group']
#
#
# Epoch   2	Mean Validation Loss:11.8722630
#
# Topic_0: ['good', 'less', 'state', 'information', 'address', 'oppose', 'fear', 'figure']
# Topic_1: ['subcommittee', 'interested', 'delay', 'policy', 'consider', 'describe', 'majority', 'attention']
# Topic_2: ['money', 'turn', 'most', 'investment', 'security', 'aware', 'authority', 'lie']
# Topic_3: ['regard', 'resolution', 'immediate', 'seem', 'large', 'introduce', 'person', 'close']
# Topic_4: ['statement', 'particular', 'attempt', 'give', 'testimony', 'value', 'produce', 'think']
# Topic_5: ['accord', 'find', 'apply', 'yield', 'late', 'oppose', 'place', 'revenue']
# Topic_6: ['next', 'requirement', 'decision', 'agency', 'particular', 'little', 'word', 'information']
# Topic_7: ['thank', 'know', 'colleague', 'preserve', 'money', 'institution', 'interested', 'good']
# Topic_8: ['general', 'many', 'condition', 'contribution', 'product', 'senator', 'program', 'appropriate']
# Topic_9: ['great', 'point', 'propose', 'capital', 'proposal', 'weapon', 'avoid', 'rest']
# Topic_10: ['free', 'republican', 'accomplish', 'dollar', 'cover', 'urge', 'rise', 'capital']
# Topic_11: ['let', 'opportunity', 'policy', 'third', 'account', 'argument', 'project', 'direction']
# Topic_12: ['full', 'wait', 'start', 'choice', 'subcommittee', 'assume', 'measure', 'hear']
# Topic_13: ['consideration', 'citizen', 'spend', 'pay', 'personnel', 'clear', 'appropriation', 'hand']
# Topic_14: ['work', 'moment', 'action', 'product', 'propose', 'intent', 'strike', 'base']
# Topic_15: ['chairman', 'friend', 'legislation', 'true', 'child', 'apply', 'prepare', 'nation']
# Topic_16: ['reach', 'hold', 'present', 'risk', 'history', 'determine', 'work', 'status']
# Topic_17: ['condition', 'request', 'principal', 'requirement', 'month', 'send', 'clerk', 'emergency']
# Topic_18: ['build', 'year', 'provision', 'matter', 'promote', 'advise', 'come', 'move']
# Topic_19: ['new', 'project', 'include', 'determine', 'justice', 'important', 'major', 'affect']
#
# Intercept: ['describe', 'fiscal', 'adopt', 'meet', 'help', 'good', 'transportation', 'group']
#
#
# Stopping at Epoch 1. Reverting to Epoch 1

# %%
tm.get_predictions(train_dataset, to_numpy=False)[0:10]
# Out:
# tensor([[0.0697],
#         [0.0683],
#         [0.1211],
#         [0.0688],
#         [0.0650],
#         [0.0661],
#         [0.1159],
#         [0.0706],
#         [0.0758],
#         [0.0651]], device='cuda:0')
