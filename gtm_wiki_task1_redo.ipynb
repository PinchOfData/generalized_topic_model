# %%
'''
To reproduce the results, first download the dataset from the following link:
https://drive.google.com/file/d/1YlS3Ojni-MFSB5f1rXgd-Su4G4kLxC3Y/view?usp=sharing

Then unzip the dataset.zip under the project directory.
'''
# Out:
# '\nTo reproduce the results, first download the dataset from the following link:\n\nThen unzip the dataset.zip under the project directory.\n'

# %%
import pandas as pd
import sys
from gtm.corpus import GTMCorpus
from gtm.gtm import GTM
import pickle as p
import os
from compute_metrics import compute
import sys

import warnings
warnings.filterwarnings('ignore')

# %%
MODEL_NAME = 'intfloat/multilingual-e5-large'

# %%
def load_examples(language='en'):
  df = pd.read_csv('./dataset/docs_original_{}.txt'.format(language), header=None, delimiter='\t')
  df.columns = ['index', 'doc_clean']
  df['language'] = language
  # df = df.head(1000)
  return df

# %%
df_en = load_examples('en')
df_zh = load_examples('zh')

print('English examples = {}'.format(len(df_en)))
print('Chinese examples = {}'.format(len(df_zh)))
# Out:
# English examples = 11043
# Chinese examples = 10135

# %%
num_en = len(df_en)
num_zh = len(df_zh)
# English always comes the first
df = pd.concat([df_en, df_zh]).reset_index()
print('Total examples = {}'.format(len(df)))
# Out:
# Total examples = 21178

# %%
def create_dataset(language='en'):
  if not os.path.exists('train_dataset_{}-{}.pkl'.format(MODEL_NAME.split('/')[1], language)):
    print('Loading examples for {}'.format(language))
    train_dataset = GTMCorpus(
      df,
      embeddings_type='SentenceTransformer',
      vectorizer_args = {'ngram_range':(1, 1), 'max_df':0.99, 'min_df':0.001, 'stop_words':'english'},
      sbert_model_to_load=MODEL_NAME,
      content=None,
      prevalence=None,
      batch_size=128,
      max_seq_length=512,
      num_en=num_en,
      num_zh=num_zh,
      language=language)

    print('Saving train_dataset_{}-{}.pkl'.format(MODEL_NAME.split('/')[1], language))
    with open('train_dataset_{}-{}.pkl'.format(MODEL_NAME.split('/')[1], language), 'wb') as f:
      p.dump(train_dataset, f)
  else:
    with open('train_dataset_{}-{}.pkl'.format(MODEL_NAME.split('/')[1], language), 'rb') as f:
      train_dataset = p.load(f)
  return train_dataset

# %%
train_dataset_en = create_dataset('en')
train_dataset_zh = create_dataset('zh')

# %%
tm_en = GTM(
    train_dataset_en,
    n_topics=6,
    doc_topic_prior='dirichlet',
    update_prior=False,
    encoder_hidden_layers=[256],
    decoder_hidden_layers=[256],
    learning_rate=1e-3,
    num_workers=0,
    patience=3,
    num_epochs=1000,
    encoder_input='bow',
    ckpt_folder='./ckpt_task1_redo_en',
    # ckpt='./ckpt_task1_redo_en/best_model.ckpt',
)
# Out:
# Epoch   1	Mean Training Loss:1421.7371607
#
# Topic_0: ['release', 'make', 'year', 'state', 'new', 'use', 'film', 'time']
# Topic_1: ['film', 'use', 'year', 'new', 'time', 'make', 'restaurant', 'food']
# Topic_2: ['new', 'film', 'release', 'know', 'make', 'use', 'include', 'year']
# Topic_3: ['album', 'release', 'woman', 'record', 'government', 'year', 'right', 'group']
# Topic_4: ['film', 'use', 'new', 'make', 'include', 'know', 'family', 'year']
# Topic_5: ['specie', 'bird', 'chinese', 'use', 'know', 'film', 'family', 'white']
#
#
#
# Epoch   2	Mean Training Loss:1344.6944238
#
# Topic_0: ['woman', 'year', 'state', 'right', 'government', 'school', 'use', 'time']
# Topic_1: ['film', 'restaurant', 'company', 'new', 'food', 'open', 'location', 'star']
# Topic_2: ['film', 'new', 'year', 'make', 'state', 'know', 'use', 'release']
# Topic_3: ['album', 'release', 'record', 'hop', 'hip', 'music', 'group', 'right']
# Topic_4: ['bird', 'specie', 'white', 'breed', 'make', 'chicken', 'black', 'genus']
# Topic_5: ['chinese', 'shrine', 'temple', 'god', 'know', 'use', 'dynasty', 'japanese']
#
#
#
# Epoch   3	Mean Training Loss:1319.5120391
#
# Topic_0: ['woman', 'right', 'law', 'sex', 'state', 'government', 'human', 'traffic']
# Topic_1: ['restaurant', 'company', 'food', 'chain', 'open', 'location', 'ice', 'use']
# Topic_2: ['film', 'star', 'kill', 'direct', 'plot', 'make', 'use', 'release']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'group', 'hip', 'single']
# Topic_4: ['bird', 'specie', 'white', 'breed', 'eagle', 'tail', 'black', 'genus']
# Topic_5: ['chinese', 'shrine', 'japanese', 'temple', 'god', 'know', 'use', 'year']
#
#
#
# Epoch   4	Mean Training Loss:1302.8167442
#
# Topic_0: ['woman', 'law', 'right', 'government', 'sex', 'child', 'traffic', 'victim']
# Topic_1: ['restaurant', 'food', 'company', 'chicken', 'open', 'chain', 'state', 'ice']
# Topic_2: ['film', 'character', 'star', 'kill', 'release', 'direct', 'series', 'use']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'feature']
# Topic_4: ['bird', 'specie', 'white', 'black', 'breed', 'tail', 'male', 'female']
# Topic_5: ['chinese', 'shrine', 'god', 'japanese', 'temple', 'use', 'school', 'confucian']
#
#
#
# Epoch   5	Mean Training Loss:1299.3772064
#
# Topic_0: ['woman', 'right', 'child', 'government', 'law', 'state', 'sex', 'traffic']
# Topic_1: ['restaurant', 'company', 'food', 'cream', 'ice', 'location', 'chain', 'sandwich']
# Topic_2: ['film', 'direct', 'star', 'release', 'character', 'kill', 'plot', 'use']
# Topic_3: ['album', 'release', 'record', 'group', 'hop', 'hip', 'music', 'single']
# Topic_4: ['specie', 'bird', 'breed', 'white', 'black', 'genus', 'tail', 'male']
# Topic_5: ['shrine', 'chinese', 'temple', 'school', 'century', 'god', 'know', 'state']
#
#
#
# Epoch   6	Mean Training Loss:1298.1691422
#
# Topic_0: ['woman', 'government', 'law', 'right', 'traffic', 'victim', 'sex', 'child']
# Topic_1: ['restaurant', 'food', 'company', 'chain', 'make', 'location', 'open', 'pizza']
# Topic_2: ['film', 'kill', 'star', 'direct', 'release', 'character', 'plot', 'action']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'group', 'single']
# Topic_4: ['specie', 'bird', 'eagle', 'white', 'breed', 'genus', 'tail', 'black']
# Topic_5: ['chinese', 'shrine', 'school', 'temple', 'dynasty', 'year', 'japanese', 'god']
#
#
#
# Epoch   7	Mean Training Loss:1296.2693489
#
# Topic_0: ['woman', 'right', 'government', 'law', 'traffic', 'sex', 'victim', 'child']
# Topic_1: ['restaurant', 'food', 'company', 'cream', 'ice', 'location', 'open', 'chain']
# Topic_2: ['film', 'kill', 'star', 'direct', 'release', 'plot', 'character', 'use']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'song']
# Topic_4: ['bird', 'specie', 'white', 'genus', 'breed', 'black', 'eagle', 'tail']
# Topic_5: ['shrine', 'chinese', 'god', 'temple', 'year', 'know', 'use', 'life']
#
#
#
# Epoch   8	Mean Training Loss:1294.1070437
#
# Topic_0: ['woman', 'law', 'sex', 'right', 'government', 'traffic', 'child', 'victim']
# Topic_1: ['restaurant', 'food', 'company', 'location', 'chain', 'open', 'cream', 'new']
# Topic_2: ['film', 'star', 'kill', 'character', 'direct', 'plot', 'release', 'series']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'group', 'song']
# Topic_4: ['bird', 'specie', 'white', 'breed', 'genus', 'tail', 'male', 'black']
# Topic_5: ['chinese', 'shrine', 'temple', 'god', 'dynasty', 'know', 'use', 'text']
#
#
#
# Epoch   9	Mean Training Loss:1294.0115794
#
# Topic_0: ['right', 'woman', 'law', 'traffic', 'government', 'sex', 'victim', 'state']
# Topic_1: ['restaurant', 'food', 'company', 'chain', 'open', 'cream', 'location', 'ice']
# Topic_2: ['film', 'star', 'direct', 'kill', 'release', 'plot', 'action', 'use']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'song', 'group']
# Topic_4: ['bird', 'specie', 'white', 'breed', 'black', 'tail', 'genus', 'eagle']
# Topic_5: ['chinese', 'shrine', 'temple', 'kami', 'use', 'century', 'know', 'japanese']
#
#
#
# Epoch  10	Mean Training Loss:1292.2120442
#
# Topic_0: ['woman', 'law', 'sex', 'right', 'traffic', 'government', 'victim', 'child']
# Topic_1: ['restaurant', 'company', 'food', 'ice', 'cream', 'location', 'open', 'chain']
# Topic_2: ['film', 'star', 'character', 'kill', 'direct', 'series', 'release', 'plot']
# Topic_3: ['album', 'release', 'record', 'hop', 'hip', 'music', 'group', 'song']
# Topic_4: ['specie', 'bird', 'white', 'breed', 'genus', 'black', 'male', 'parrot']
# Topic_5: ['chinese', 'shrine', 'temple', 'god', 'use', 'japanese', 'shinto', 'know']
#
#
#
# Epoch  11	Mean Training Loss:1291.0075345
#
# Topic_0: ['law', 'sex', 'traffic', 'woman', 'government', 'right', 'victim', 'child']
# Topic_1: ['restaurant', 'food', 'company', 'location', 'chain', 'open', 'new', 'cream']
# Topic_2: ['film', 'star', 'character', 'kill', 'series', 'direct', 'use', 'release']
# Topic_3: ['release', 'album', 'record', 'music', 'song', 'group', 'hop', 'hip']
# Topic_4: ['bird', 'specie', 'white', 'black', 'breed', 'eagle', 'genus', 'tail']
# Topic_5: ['chinese', 'shrine', 'temple', 'use', 'know', 'century', 'dynasty', 'school']
#
#
#
# Epoch  12	Mean Training Loss:1290.4613199
#
# Topic_0: ['law', 'sex', 'traffic', 'right', 'woman', 'government', 'victim', 'child']
# Topic_1: ['company', 'restaurant', 'food', 'chain', 'product', 'location', 'new', 'open']
# Topic_2: ['film', 'star', 'kill', 'character', 'release', 'direct', 'series', 'use']
# Topic_3: ['album', 'release', 'record', 'music', 'feature', 'hop', 'song', 'group']
# Topic_4: ['specie', 'bird', 'white', 'black', 'breed', 'genus', 'tail', 'parrot']
# Topic_5: ['shrine', 'chinese', 'temple', 'god', 'know', 'text', 'century', 'school']
#
#
#
# Epoch  13	Mean Training Loss:1288.7109237
#
# Topic_0: ['government', 'traffic', 'right', 'law', 'sex', 'victim', 'woman', 'child']
# Topic_1: ['restaurant', 'company', 'food', 'location', 'open', 'cream', 'chain', 'ice']
# Topic_2: ['film', 'star', 'kill', 'character', 'direct', 'release', 'use', 'series']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'song']
# Topic_4: ['specie', 'bird', 'white', 'genus', 'breed', 'eagle', 'tail', 'black']
# Topic_5: ['chinese', 'shrine', 'temple', 'dynasty', 'shinto', 'god', 'use', 'century']
#
#
#
# Epoch  14	Mean Training Loss:1287.9462019
#
# Topic_0: ['traffic', 'government', 'sex', 'law', 'victim', 'child', 'right', 'sexual']
# Topic_1: ['restaurant', 'company', 'food', 'chain', 'location', 'open', 'ice', 'cream']
# Topic_2: ['film', 'star', 'kill', 'character', 'direct', 'series', 'release', 'use']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'feature']
# Topic_4: ['specie', 'bird', 'white', 'genus', 'tail', 'eagle', 'black', 'wing']
# Topic_5: ['shrine', 'chinese', 'temple', 'dynasty', 'kami', 'know', 'god', 'shinto']
#
#
#
# Epoch  15	Mean Training Loss:1286.5545369
#
# Topic_0: ['government', 'traffic', 'victim', 'sex', 'law', 'woman', 'child', 'right']
# Topic_1: ['company', 'restaurant', 'food', 'product', 'open', 'location', 'chain', 'sandwich']
# Topic_2: ['film', 'star', 'kill', 'character', 'direct', 'series', 'release', 'plot']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'song', 'group']
# Topic_4: ['specie', 'bird', 'white', 'genus', 'black', 'tail', 'eagle', 'parrot']
# Topic_5: ['chinese', 'shrine', 'temple', 'kami', 'century', 'school', 'text', 'confucius']
#
#
#
# Epoch  16	Mean Training Loss:1285.5244292
#
# Topic_0: ['sex', 'traffic', 'government', 'law', 'victim', 'right', 'child', 'woman']
# Topic_1: ['restaurant', 'company', 'food', 'location', 'chain', 'ice', 'cream', 'open']
# Topic_2: ['film', 'star', 'kill', 'character', 'direct', 'series', 'release', 'make']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'group', 'hip', 'single']
# Topic_4: ['specie', 'bird', 'white', 'black', 'genus', 'eagle', 'tail', 'male']
# Topic_5: ['shrine', 'chinese', 'school', 'century', 'god', 'japanese', 'text', 'know']
#
#
#
# Epoch  17	Mean Training Loss:1285.2719116
#
# Topic_0: ['traffic', 'sex', 'government', 'law', 'victim', 'right', 'child', 'woman']
# Topic_1: ['restaurant', 'company', 'ice', 'cream', 'food', 'chain', 'open', 'new']
# Topic_2: ['film', 'star', 'character', 'kill', 'direct', 'series', 'release', 'use']
# Topic_3: ['album', 'release', 'record', 'song', 'group', 'music', 'hop', 'hip']
# Topic_4: ['specie', 'bird', 'black', 'white', 'eagle', 'genus', 'tail', 'feather']
# Topic_5: ['shrine', 'chinese', 'temple', 'kami', 'century', 'dynasty', 'god', 'emperor']
#
#
#
# Epoch  18	Mean Training Loss:1282.8897920
#
# Topic_0: ['traffic', 'victim', 'government', 'law', 'sex', 'right', 'child', 'trafficking']
# Topic_1: ['restaurant', 'company', 'food', 'cream', 'ice', 'chain', 'open', 'store']
# Topic_2: ['film', 'kill', 'character', 'star', 'direct', 'use', 'series', 'make']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'group', 'feature']
# Topic_4: ['specie', 'bird', 'white', 'black', 'tail', 'genus', 'forest', 'owl']
# Topic_5: ['chinese', 'shrine', 'kami', 'temple', 'text', 'god', 'shinto', 'dynasty']
#
#
#
# Epoch  19	Mean Training Loss:1282.4342676
#
# Topic_0: ['traffic', 'sex', 'law', 'government', 'victim', 'child', 'sexual', 'right']
# Topic_1: ['restaurant', 'company', 'cream', 'ice', 'chain', 'food', 'location', 'open']
# Topic_2: ['film', 'star', 'character', 'kill', 'series', 'direct', 'use', 'release']
# Topic_3: ['album', 'release', 'record', 'hop', 'music', 'hip', 'group', 'song']
# Topic_4: ['specie', 'bird', 'black', 'white', 'genus', 'tail', 'parrot', 'owl']
# Topic_5: ['chinese', 'shrine', 'temple', 'dynasty', 'century', 'god', 'kami', 'religion']
#
#
#
# Epoch  20	Mean Training Loss:1281.1027507
#
# Topic_0: ['traffic', 'sex', 'victim', 'government', 'right', 'law', 'child', 'woman']
# Topic_1: ['restaurant', 'company', 'chain', 'food', 'location', 'open', 'cream', 'ice']
# Topic_2: ['film', 'star', 'kill', 'character', 'series', 'direct', 'release', 'time']
# Topic_3: ['album', 'release', 'record', 'hop', 'hip', 'music', 'song', 'feature']
# Topic_4: ['specie', 'bird', 'white', 'eagle', 'black', 'genus', 'tail', 'male']
# Topic_5: ['shrine', 'chinese', 'temple', 'god', 'kami', 'shinto', 'dynasty', 'text']
#
#
#
# Epoch  21	Mean Training Loss:1280.4431392
#
# Topic_0: ['traffic', 'victim', 'sex', 'government', 'law', 'trafficking', 'child', 'sexual']
# Topic_1: ['restaurant', 'company', 'food', 'location', 'chain', 'open', 'ice', 'cream']
# Topic_2: ['film', 'kill', 'character', 'star', 'series', 'use', 'release', 'direct']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'feature', 'hop', 'single']
# Topic_4: ['specie', 'bird', 'black', 'white', 'genus', 'eagle', 'tail', 'wing']
# Topic_5: ['chinese', 'shrine', 'dynasty', 'emperor', 'shinto', 'school', 'kami', 'temple']
#
#
#
# Epoch  22	Mean Training Loss:1280.5539501
#
# Topic_0: ['traffic', 'sex', 'victim', 'government', 'child', 'law', 'trafficking', 'sexual']
# Topic_1: ['company', 'restaurant', 'location', 'ice', 'cream', 'food', 'chain', 'open']
# Topic_2: ['film', 'star', 'character', 'kill', 'series', 'use', 'trek', 'make']
# Topic_3: ['album', 'release', 'record', 'group', 'music', 'hop', 'hip', 'feature']
# Topic_4: ['specie', 'bird', 'white', 'genus', 'black', 'tail', 'wing', 'male']
# Topic_5: ['shrine', 'chinese', 'text', 'temple', 'dynasty', 'school', 'shinto', 'god']
#
#
#
# Epoch  23	Mean Training Loss:1280.5387337
#
# Topic_0: ['traffic', 'victim', 'sex', 'government', 'child', 'law', 'trafficking', 'country']
# Topic_1: ['company', 'restaurant', 'ice', 'chain', 'cream', 'food', 'location', 'open']
# Topic_2: ['film', 'character', 'kill', 'star', 'use', 'series', 'make', 'escape']
# Topic_3: ['album', 'release', 'record', 'group', 'hop', 'music', 'hip', 'song']
# Topic_4: ['specie', 'bird', 'white', 'genus', 'tail', 'black', 'eagle', 'female']
# Topic_5: ['chinese', 'shrine', 'dynasty', 'scholar', 'century', 'temple', 'shinto', 'text']
#
#
#
# Epoch  24	Mean Training Loss:1278.3364431
#
# Topic_0: ['sex', 'traffic', 'law', 'government', 'victim', 'child', 'sexual', 'marriage']
# Topic_1: ['restaurant', 'company', 'chain', 'food', 'open', 'cream', 'ice', 'location']
# Topic_2: ['film', 'character', 'kill', 'star', 'series', 'use', 'alien', 'trek']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'group', 'hip', 'feature']
# Topic_4: ['specie', 'bird', 'white', 'black', 'genus', 'tail', 'eagle', 'wing']
# Topic_5: ['shrine', 'chinese', 'kami', 'temple', 'century', 'dynasty', 'text', 'religion']
#
#
#
# Epoch  25	Mean Training Loss:1278.1919076
#
# Topic_0: ['traffic', 'sex', 'victim', 'government', 'law', 'trafficking', 'sexual', 'child']
# Topic_1: ['restaurant', 'chain', 'company', 'location', 'open', 'food', 'ice', 'cream']
# Topic_2: ['film', 'star', 'character', 'kill', 'series', 'use', 'make', 'ship']
# Topic_3: ['release', 'album', 'record', 'group', 'hop', 'song', 'music', 'single']
# Topic_4: ['specie', 'bird', 'genus', 'white', 'tail', 'black', 'family', 'male']
# Topic_5: ['shrine', 'chinese', 'text', 'dynasty', 'temple', 'shinto', 'century', 'kami']
#
#
#
# Epoch  26	Mean Training Loss:1275.8491130
#
# Topic_0: ['traffic', 'victim', 'sex', 'government', 'law', 'child', 'sexual', 'trafficking']
# Topic_1: ['company', 'restaurant', 'ice', 'chain', 'cream', 'food', 'location', 'open']
# Topic_2: ['film', 'character', 'kill', 'star', 'series', 'trek', 'make', 'use']
# Topic_3: ['album', 'release', 'record', 'group', 'single', 'hop', 'song', 'music']
# Topic_4: ['specie', 'bird', 'genus', 'white', 'black', 'island', 'eagle', 'owl']
# Topic_5: ['shrine', 'chinese', 'kami', 'god', 'dynasty', 'emperor', 'text', 'shinto']
#
#
#
# Epoch  27	Mean Training Loss:1276.5118786
#
# Topic_0: ['traffic', 'sex', 'victim', 'government', 'law', 'sexual', 'trafficking', 'child']
# Topic_1: ['restaurant', 'company', 'food', 'location', 'chain', 'open', 'store', 'cream']
# Topic_2: ['film', 'star', 'kill', 'character', 'trek', 'series', 'use', 'alien']
# Topic_3: ['album', 'release', 'record', 'group', 'hop', 'song', 'hip', 'new']
# Topic_4: ['specie', 'bird', 'black', 'white', 'genus', 'tail', 'parrot', 'male']
# Topic_5: ['shrine', 'chinese', 'kami', 'text', 'god', 'religion', 'dynasty', 'scholar']
#
#
#
# Epoch  28	Mean Training Loss:1274.9587367
#
# Topic_0: ['traffic', 'victim', 'sex', 'government', 'law', 'trafficking', 'child', 'sexual']
# Topic_1: ['company', 'restaurant', 'ice', 'cream', 'chain', 'store', 'location', 'open']
# Topic_2: ['film', 'character', 'kill', 'star', 'use', 'trek', 'series', 'escape']
# Topic_3: ['album', 'release', 'record', 'hop', 'hip', 'single', 'group', 'music']
# Topic_4: ['specie', 'bird', 'genus', 'white', 'tail', 'family', 'black', 'forest']
# Topic_5: ['shrine', 'chinese', 'text', 'temple', 'dynasty', 'kami', 'shinto', 'buddhist']
#
#
#
# Epoch  29	Mean Training Loss:1275.5293089
#
# Topic_0: ['traffic', 'victim', 'government', 'sex', 'child', 'trafficking', 'law', 'country']
# Topic_1: ['company', 'restaurant', 'location', 'chain', 'open', 'ice', 'cream', 'food']
# Topic_2: ['film', 'kill', 'star', 'character', 'series', 'use', 'release', 'trek']
# Topic_3: ['release', 'album', 'record', 'single', 'feature', 'hop', 'hip', 'group']
# Topic_4: ['specie', 'bird', 'genus', 'white', 'tail', 'wing', 'black', 'long']
# Topic_5: ['shrine', 'chinese', 'text', 'god', 'kami', 'dynasty', 'shinto', 'confucius']
#
#
#
# Epoch  30	Mean Training Loss:1275.1126473
#
# Topic_0: ['traffic', 'victim', 'government', 'sex', 'trafficking', 'child', 'sexual', 'law']
# Topic_1: ['restaurant', 'company', 'location', 'cream', 'ice', 'chain', 'open', 'food']
# Topic_2: ['film', 'character', 'star', 'kill', 'trek', 'ship', 'use', 'series']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'single', 'hip']
# Topic_4: ['specie', 'bird', 'tail', 'white', 'genus', 'eagle', 'black', 'male']
# Topic_5: ['shrine', 'chinese', 'kami', 'school', 'text', 'shinto', 'dynasty', 'confucius']
#
#
#
# Epoch  31	Mean Training Loss:1275.1078050
#
# Topic_0: ['traffic', 'victim', 'sex', 'government', 'child', 'law', 'trafficking', 'country']
# Topic_1: ['company', 'restaurant', 'chain', 'ice', 'food', 'location', 'store', 'cream']
# Topic_2: ['film', 'kill', 'star', 'character', 'use', 'trek', 'series', 'escape']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'single', 'song']
# Topic_4: ['specie', 'bird', 'white', 'black', 'genus', 'male', 'tail', 'long']
# Topic_5: ['shrine', 'kami', 'chinese', 'dynasty', 'text', 'shinto', 'school', 'god']
#
#
#
# Early stopping at Epoch 31. Reverting to Epoch 28

# %%
print('Computing metrics for English... BOW')
compute(tm_en, train_dataset_en, './output_task1_BOW_en_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for English... BOW
# 3 5 0 1 2 4
# f1_macro = 0.9397780386824346
# f1_micro = 0.941139183192973
# acc = 0.941139183192973
# ars = 0.8682099367464389
# --------------------------------------------------

# %%
tm_zh = GTM(
    train_dataset_zh,
    n_topics=6,
    doc_topic_prior='dirichlet',
    update_prior=False,
    encoder_hidden_layers=[256],
    decoder_hidden_layers=[256],
    learning_rate=1e-3,
    num_workers=0,
    patience=3,
    num_epochs=1000,
    encoder_input='bow',
    ckpt_folder='./ckpt_task1_redo_zh',
    # ckpt='./ckpt_task1_redo_zh/best_model.ckpt',
)
# Out:
# Epoch   1	Mean Training Loss:853.1959248
#
# Topic_0: ['台湾', '中国', '电影', '美国', '香港', '他们', '日本', '英语']
# Topic_1: ['中国', '台湾', '认为', '美国', '国家', '他们', '地区', '历史']
# Topic_2: ['台湾', '中国', '美国', '电影', '大学', '日本', '香港', '第一']
# Topic_3: ['台湾', '大学', '音乐', '电影', '中国', '美国', '第一', '专辑']
# Topic_4: ['中国', '台湾', '日本', '美国', '香港', '主要', '电影', '地区']
# Topic_5: ['中国', '学名', '地区', '台湾', '主要', '可以', '分布', '动物']
#
#
#
# Epoch   2	Mean Training Loss:799.8463066
#
# Topic_0: ['电影', '他们', '自己', '上映', '美国', '故事', '动画', '发现']
# Topic_1: ['主义', '美国', '中国', '运动', '年月', '教会', '台湾', '政府']
# Topic_2: ['美国', '电影', '中国', '台湾', '英语', '日本', '作品', '第一']
# Topic_3: ['台湾', '音乐', '大学', '中国', '专辑', '担任', '歌手', '乐团']
# Topic_4: ['台湾', '中国', '学名', '香港', '动物', '分布', '地区', '主要']
# Topic_5: ['学名', '中国', '地区', '分布', '台湾', '物种', '牠们', '动物']
#
#
#
# Epoch   3	Mean Training Loss:790.3492098
#
# Topic_0: ['电影', '他们', '上映', '自己', '动画', '美国', '发现', '剧情']
# Topic_1: ['台湾', '主义', '中国', '运动', '政府', '年月', '认为', '革命']
# Topic_2: ['电影', '美国', '作品', '台湾', '日本', '英语', '中国', '自己']
# Topic_3: ['台湾', '音乐', '大学', '专辑', '乐团', '中国', '担任', '歌手']
# Topic_4: ['台湾', '学名', '中国', '动物', '地区', '香港', '物种', '分布']
# Topic_5: ['学名', '地区', '分布', '中国', '物种', '牠们', '台湾', '可以']
#
#
#
# Epoch   4	Mean Training Loss:788.3746845
#
# Topic_0: ['电影', '他们', '发现', '自己', '上映', '剧情', '开始', '美国']
# Topic_1: ['政府', '年月', '台湾', '主义', '中国', '国家', '运动', '组织']
# Topic_2: ['电影', '美国', '作品', '动画', '上映', '故事', '大学', '日本']
# Topic_3: ['大学', '台湾', '音乐', '专辑', '中国', '乐团', '担任', '第一']
# Topic_4: ['台湾', '中国', '学名', '动物', '香港', '地区', '食品', '物种']
# Topic_5: ['学名', '中国', '分布', '地区', '物种', '台湾', '牠们', '植物']
#
#
#
# Epoch   5	Mean Training Loss:786.1371631
#
# Topic_0: ['电影', '他们', '自己', '发现', '上映', '美国', '动画', '剧情']
# Topic_1: ['主义', '台湾', '中国', '政府', '运动', '美国', '年月', '革命']
# Topic_2: ['电影', '美国', '上映', '动画', '故事', '作品', '英语', '剧情']
# Topic_3: ['台湾', '大学', '音乐', '专辑', '中国', '乐团', '学院', '第一']
# Topic_4: ['台湾', '中国', '动物', '学名', '地区', '香港', '物种', '可以']
# Topic_5: ['学名', '分布', '中国', '地区', '物种', '牠们', '台湾', '厘米']
#
#
#
# Epoch   6	Mean Training Loss:784.3177471
#
# Topic_0: ['电影', '自己', '他们', '发现', '上映', '剧情', '美国', '动画']
# Topic_1: ['台湾', '主义', '运动', '中国', '年月', '政府', '组织', '革命']
# Topic_2: ['电影', '美国', '上映', '作品', '动画', '日本', '导演', '英语']
# Topic_3: ['音乐', '台湾', '大学', '专辑', '乐团', '歌手', '中国', '第一']
# Topic_4: ['动物', '台湾', '学名', '中国', '地区', '植物', '主要', '可以']
# Topic_5: ['学名', '分布', '牠们', '地区', '中国', '台湾', '物种', '厘米']
#
#
#
# Epoch   7	Mean Training Loss:783.8402829
#
# Topic_0: ['电影', '他们', '发现', '自己', '上映', '美国', '开始', '动画']
# Topic_1: ['台湾', '年月', '中国', '政府', '主义', '运动', '美国', '国家']
# Topic_2: ['电影', '动画', '上映', '美国', '作品', '导演', '制作', '故事']
# Topic_3: ['台湾', '音乐', '大学', '专辑', '中国', '乐团', '歌手', '发行']
# Topic_4: ['中国', '动物', '台湾', '地区', '香港', '可以', '主要', '学名']
# Topic_5: ['学名', '分布', '牠们', '中国', '地区', '台湾', '物种', '亚种']
#
#
#
# Epoch   8	Mean Training Loss:782.4968471
#
# Topic_0: ['他们', '电影', '发现', '自己', '开始', '美国', '上映', '动画']
# Topic_1: ['台湾', '中国', '运动', '政府', '美国', '主义', '年月', '政治']
# Topic_2: ['电影', '动画', '作品', '上映', '美国', '英语', '制作', '故事']
# Topic_3: ['音乐', '台湾', '专辑', '大学', '中国', '乐团', '歌手', '第一']
# Topic_4: ['台湾', '中国', '动物', '地区', '可以', '食用', '植物', '学名']
# Topic_5: ['学名', '分布', '台湾', '中国', '牠们', '物种', '地区', '植物']
#
#
#
# Epoch   9	Mean Training Loss:781.8757409
#
# Topic_0: ['电影', '他们', '自己', '发现', '上映', '开始', '剧情', '美国']
# Topic_1: ['台湾', '年月', '主义', '中国', '运动', '美国', '政府', '政治']
# Topic_2: ['电影', '动画', '作品', '美国', '上映', '制作', '香港', '导演']
# Topic_3: ['音乐', '台湾', '大学', '专辑', '中国', '乐团', '歌手', '发行']
# Topic_4: ['中国', '地区', '台湾', '可以', '食品', '香港', '动物', '主要']
# Topic_5: ['学名', '中国', '台湾', '分布', '牠们', '地区', '物种', '白色']
#
#
#
# Epoch  10	Mean Training Loss:781.2985990
#
# Topic_0: ['电影', '他们', '自己', '发现', '开始', '上映', '美国', '剧情']
# Topic_1: ['台湾', '主义', '中国', '年月', '运动', '政府', '中华', '国家']
# Topic_2: ['电影', '动画', '作品', '制作', '上映', '美国', '香港', '故事']
# Topic_3: ['台湾', '音乐', '大学', '专辑', '乐团', '中国', '歌手', '节目']
# Topic_4: ['台湾', '动物', '可以', '中国', '食用', '地区', '主要', '学名']
# Topic_5: ['学名', '台湾', '分布', '牠们', '中国', '物种', '地区', '动物']
#
#
#
# Epoch  11	Mean Training Loss:779.9534651
#
# Topic_0: ['他们', '电影', '自己', '发现', '上映', '美国', '开始', '剧情']
# Topic_1: ['台湾', '政府', '主义', '年月', '中国', '运动', '组织', '教会']
# Topic_2: ['电影', '美国', '作品', '动画', '上映', '制作', '故事', '香港']
# Topic_3: ['音乐', '台湾', '大学', '专辑', '中国', '乐团', '歌手', '学院']
# Topic_4: ['中国', '动物', '台湾', '可以', '地区', '学名', '主要', '食用']
# Topic_5: ['学名', '分布', '牠们', '台湾', '中国', '物种', '地区', '动物']
#
#
#
# Epoch  12	Mean Training Loss:778.0817311
#
# Topic_0: ['他们', '电影', '发现', '自己', '上映', '剧情', '开始', '美国']
# Topic_1: ['主义', '中国', '台湾', '国家', '年月', '政府', '组织', '运动']
# Topic_2: ['电影', '动画', '作品', '上映', '香港', '美国', '故事', '制作']
# Topic_3: ['音乐', '台湾', '大学', '专辑', '乐团', '中国', '发行', '第一']
# Topic_4: ['中国', '可以', '地区', '主要', '学名', '台湾', '香港', '使用']
# Topic_5: ['学名', '分布', '牠们', '中国', '台湾', '物种', '地区', '黑色']
#
#
#
# Epoch  13	Mean Training Loss:777.4037456
#
# Topic_0: ['电影', '他们', '自己', '发现', '开始', '上映', '美国', '剧情']
# Topic_1: ['主义', '台湾', '政府', '中国', '运动', '年月', '组织', '美国']
# Topic_2: ['电影', '动画', '作品', '制作', '上映', '香港', '美国', '故事']
# Topic_3: ['音乐', '台湾', '专辑', '大学', '乐团', '唱片', '歌手', '中国']
# Topic_4: ['地区', '中国', '可以', '植物', '食物', '台湾', '食用', '学名']
# Topic_5: ['学名', '分布', '物种', '牠们', '台湾', '中国', '地区', '黑色']
#
#
#
# Epoch  14	Mean Training Loss:776.4153684
#
# Topic_0: ['电影', '发现', '自己', '他们', '上映', '美国', '开始', '剧情']
# Topic_1: ['主义', '台湾', '中国', '教会', '政府', '组织', '国家', '运动']
# Topic_2: ['电影', '动画', '作品', '美国', '日本', '上映', '制作', '香港']
# Topic_3: ['台湾', '音乐', '专辑', '乐团', '大学', '中国', '发行', '歌手']
# Topic_4: ['地区', '食用', '可以', '台湾', '食品', '中国', '植物', '学名']
# Topic_5: ['学名', '牠们', '台湾', '分布', '物种', '中国', '地区', '厘米']
#
#
#
# Epoch  15	Mean Training Loss:776.2642761
#
# Topic_0: ['他们', '电影', '自己', '发现', '上映', '开始', '美国', '所有']
# Topic_1: ['主义', '国家', '组织', '台湾', '中国', '认为', '运动', '社会']
# Topic_2: ['电影', '动画', '作品', '上映', '美国', '香港', '制作', '故事']
# Topic_3: ['音乐', '台湾', '专辑', '乐团', '歌手', '大学', '第一', '唱片']
# Topic_4: ['可以', '地区', '中国', '食用', '植物', '使用', '主要', '台湾']
# Topic_5: ['学名', '牠们', '分布', '物种', '台湾', '中国', '动物', '特征']
#
#
#
# Epoch  16	Mean Training Loss:775.2144848
#
# Topic_0: ['电影', '他们', '自己', '发现', '上映', '美国', '开始', '剧情']
# Topic_1: ['主义', '教会', '中国', '国家', '组织', '伊斯兰', '台湾', '宗教']
# Topic_2: ['电影', '动画', '作品', '制作', 'gundam', '美国', '系列', '日本']
# Topic_3: ['音乐', '台湾', '专辑', '乐团', '大学', '歌手', '唱片', '节目']
# Topic_4: ['中国', '地区', '台湾', '可以', '食用', '植物', '主要', '制作']
# Topic_5: ['学名', '台湾', '牠们', '分布', '中国', '地区', '物种', '动物']
#
#
#
# Epoch  17	Mean Training Loss:773.0883626
#
# Topic_0: ['他们', '发现', '自己', '电影', '最后', '开始', '上映', '美国']
# Topic_1: ['主义', '社会', '国家', '教会', '革命', '运动', '组织', '中国']
# Topic_2: ['电影', '动画', '作品', '香港', '制作', '日本', '美国', '上映']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '歌手', '发行', '大学', '唱片']
# Topic_4: ['中国', '食用', '植物', '地区', '可以', '台湾', '食品', '品种']
# Topic_5: ['学名', '分布', '牠们', '台湾', '中国', '物种', '亚种', '动物']
#
#
#
# Epoch  18	Mean Training Loss:772.9360210
#
# Topic_0: ['他们', '电影', '自己', '发现', '开始', '美国', '上映', '最后']
# Topic_1: ['主义', '教会', '运动', '国家', '中国', '伊斯兰', '组织', '认为']
# Topic_2: ['电影', '作品', '香港', '动画', '日本', '系列', '制作', '美国']
# Topic_3: ['台湾', '音乐', '专辑', '乐团', '歌手', '发行', '唱片', '第一']
# Topic_4: ['可以', '中国', '地区', '植物', '食品', '食用', '台湾', '学名']
# Topic_5: ['学名', '分布', '台湾', '物种', '中国', '牠们', '动物', '厘米']
#
#
#
# Epoch  19	Mean Training Loss:771.5004718
#
# Topic_0: ['他们', '电影', '发现', '自己', '最后', '开始', '美国', '上映']
# Topic_1: ['主义', '组织', '国家', '中国', '教会', '社会', '革命', '国际']
# Topic_2: ['电影', '作品', '动画', '制作', '香港', '日本', '系列', '美国']
# Topic_3: ['音乐', '台湾', '专辑', '乐团', '节目', '歌手', '发行', '演出']
# Topic_4: ['植物', '中国', '地区', '主要', '食用', '学名', '可以', '台湾']
# Topic_5: ['学名', '分布', '牠们', '中国', '物种', '台湾', '亚种', '动物']
#
#
#
# Epoch  20	Mean Training Loss:772.2808206
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '上映', '美国', '于是']
# Topic_1: ['主义', '教会', '认为', '国家', '政府', '社会', '伊斯兰', '运动']
# Topic_2: ['电影', '作品', '动画', '制作', '香港', 'gundam', '上映', '系列']
# Topic_3: ['台湾', '音乐', '专辑', '乐团', '歌手', '唱片', '节目', '发行']
# Topic_4: ['可以', '食用', '植物', '中国', '地区', '台湾', '学名', '制作']
# Topic_5: ['学名', '牠们', '台湾', '分布', '中国', '物种', '动物', '分佈']
#
#
#
# Epoch  21	Mean Training Loss:770.6319513
#
# Topic_0: ['电影', '他们', '自己', '发现', '上映', '美国', '开始', '最后']
# Topic_1: ['主义', '教会', '组织', '宗教', '国家', '国际', '革命', '认为']
# Topic_2: ['电影', '动画', '作品', '香港', '制作', 'gundam', '日本', '上映']
# Topic_3: ['音乐', '专辑', '台湾', '歌手', '乐团', '发行', '唱片', '第一']
# Topic_4: ['可以', '食用', '主要', '中国', '地区', '制作', '使用', '植物']
# Topic_5: ['牠们', '学名', '台湾', '中国', '分布', '物种', '动物', '黑色']
#
#
#
# Epoch  22	Mean Training Loss:771.3460379
#
# Topic_0: ['他们', '电影', '自己', '发现', '美国', '上映', '开始', '最后']
# Topic_1: ['主义', '教会', '伊斯兰', '组织', '他们', '穆斯林', '国家', '社会']
# Topic_2: ['电影', '动画', '作品', '香港', '系列', 'gundam', '制作', '日本']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '发行', '歌手', '唱片', '节目']
# Topic_4: ['可以', '食用', '植物', '地区', '食品', '制作', '中国', '主要']
# Topic_5: ['学名', '牠们', '中国', '分布', '台湾', '物种', '动物', '地区']
#
#
#
# Epoch  23	Mean Training Loss:769.0648554
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '最后', '美国', '上映']
# Topic_1: ['主义', '教会', '社会', '组织', '国家', '认为', '革命', '运动']
# Topic_2: ['电影', '动画', '作品', '香港', '日本', '系列', '制作', '美国']
# Topic_3: ['台湾', '专辑', '音乐', '乐团', '发行', '歌手', '唱片', '第一']
# Topic_4: ['植物', '食用', '可以', '地区', '主要', '中国', '食品', '制作']
# Topic_5: ['学名', '分布', '台湾', '物种', '牠们', '中国', '动物', '地区']
#
#
#
# Epoch  24	Mean Training Loss:768.0953849
#
# Topic_0: ['他们', '发现', '电影', '自己', '开始', '美国', '上映', '最后']
# Topic_1: ['主义', '教会', '国际', '国家', '组织', '社会', '基督教', '认为']
# Topic_2: ['电影', '动画', '作品', '香港', '系列', '制作', '日本', '剧场']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '歌手', '唱片', '发行', '演出']
# Topic_4: ['食用', '可以', '植物', '地区', '中国', '常见', '使用', '食品']
# Topic_5: ['学名', '物种', '分布', '台湾', '中国', '牠们', '动物', '分佈']
#
#
#
# Epoch  25	Mean Training Loss:767.7718627
#
# Topic_0: ['他们', '电影', '发现', '自己', '开始', '美国', '最后', '决定']
# Topic_1: ['主义', '教会', '伊斯兰', '国家', '运动', '组织', '社会', '认为']
# Topic_2: ['电影', '系列', '作品', '香港', '动画', '日本', '制作', 'gundam']
# Topic_3: ['专辑', '台湾', '音乐', '乐团', '发行', '歌手', '唱片', '创作']
# Topic_4: ['可以', '食品', '食用', '地区', '植物', '主要', '一般', '中国']
# Topic_5: ['学名', '台湾', '牠们', '分布', '物种', '中国', '黑色', '特征']
#
#
#
# Epoch  26	Mean Training Loss:766.5467249
#
# Topic_0: ['他们', '发现', '电影', '自己', '开始', '美国', '最后', '上映']
# Topic_1: ['主义', '国际', '社会主义', '社会', '革命', '马克思', '教会', '组织']
# Topic_2: ['作品', '动画', '电影', '香港', '制作', '日本', 'gundam', '系列']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '发行', '唱片', '歌手', '演唱会']
# Topic_4: ['食用', '植物', '可以', '主要', '食品', '地区', '使用', '作为']
# Topic_5: ['学名', '牠们', '分布', '动物', '物种', '台湾', '中国', '地区']
#
#
#
# Epoch  27	Mean Training Loss:767.7801836
#
# Topic_0: ['他们', '电影', '发现', '自己', '最后', '美国', '开始', '于是']
# Topic_1: ['主义', '国家', '运动', '革命', '国际', '组织', '教会', '社会']
# Topic_2: ['电影', '动画', '作品', '香港', '系列', '制作', '日本', 'gundam']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '发行', '歌手', '创作', '唱片']
# Topic_4: ['食用', '可以', '植物', '食品', '中国', '使用', '制作', '地区']
# Topic_5: ['学名', '分布', '物种', '中国', '牠们', '台湾', '动物', '特征']
#
#
#
# Epoch  28	Mean Training Loss:764.9771790
#
# Topic_0: ['他们', '发现', '自己', '电影', '于是', '上映', '开始', '最后']
# Topic_1: ['主义', '国际', '组织', '国家', '社会主义', '社会', '运动', '革命']
# Topic_2: ['作品', '动画', '电影', '香港', '制作', '系列', 'gundam', '日本']
# Topic_3: ['专辑', '台湾', '音乐', '乐团', '发行', '唱片', '歌手', '演唱会']
# Topic_4: ['食用', '植物', '可以', '主要', '地区', '制作', '使用', '中国']
# Topic_5: ['学名', '分布', '牠们', '动物', '中国', '物种', '亚种', '台湾']
#
#
#
# Epoch  29	Mean Training Loss:765.6474569
#
# Topic_0: ['他们', '自己', '电影', '发现', '开始', '最后', '美国', '所有']
# Topic_1: ['主义', '国家', '马克思', '国际', '组织', '社会', '社会主义', '帝国']
# Topic_2: ['电影', '动画', '作品', '制作', '香港', '日本', '系列', 'gundam']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '发行', '歌手', '唱片', '演唱会']
# Topic_4: ['可以', '食用', '植物', '地区', '食品', '主要', '制作', '一般']
# Topic_5: ['学名', '分布', '物种', '中国', '牠们', '台湾', '亚种', '地区']
#
#
#
# Epoch  30	Mean Training Loss:763.4866525
#
# Topic_0: ['自己', '他们', '电影', '发现', '美国', '开始', '最后', '上映']
# Topic_1: ['主义', '国际', '社会', '革命', '社会主义', '马克思', '组织', '国家']
# Topic_2: ['作品', '动画', '电影', '系列', '日本', '香港', '制作', '剧场']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '歌手', '发行', '唱片', '演唱会']
# Topic_4: ['食用', '食品', '植物', '可以', '主要', '地区', '制作', '中国']
# Topic_5: ['学名', '分布', '牠们', '中国', '物种', '台湾', '地区', '动物']
#
#
#
# Epoch  31	Mean Training Loss:764.9346709
#
# Topic_0: ['他们', '自己', '发现', '电影', '美国', '开始', '上映', '最后']
# Topic_1: ['主义', '国际', '社会', '革命', '马克思', '组织', '国家', '社会主义']
# Topic_2: ['作品', '动画', '系列', '日本', '香港', '电影', '剧场', '制作']
# Topic_3: ['音乐', '乐团', '专辑', '台湾', '唱片', '发行', '歌手', '创作']
# Topic_4: ['食用', '可以', '食品', '地区', '植物', '常见', '中国', '食物']
# Topic_5: ['学名', '牠们', '分布', '中国', '黑色', '物种', '分佈', '它们']
#
#
#
# Epoch  32	Mean Training Loss:762.8732378
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '美国', '所有', '最后']
# Topic_1: ['主义', '组织', '社会主义', '国际', '社会', '马克思', '革命', '工人']
# Topic_2: ['香港', '作品', '动画', '日本', '系列', '电影', 'gundam', '制作']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '演唱会', '歌手', '创作']
# Topic_4: ['植物', '可以', '食用', '食品', '食物', '地区', '常见', '主要']
# Topic_5: ['学名', '牠们', '分布', '中国', '物种', '台湾', '亚种', '动物']
#
#
#
# Epoch  33	Mean Training Loss:761.9857876
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '上映', '最后', '于是']
# Topic_1: ['主义', '社会主义', '国际', '马克思', '社会', '组织', '国家', '革命']
# Topic_2: ['作品', '战士', '电影', '香港', 'gundam', '动画', '系列', '机动']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '歌手', '唱片', '演出']
# Topic_4: ['植物', '地区', '可以', '食用', '主要', '称为', '使用', '中国']
# Topic_5: ['学名', '牠们', '分布', '中国', '台湾', '物种', '亚种', '分佈']
#
#
#
# Epoch  34	Mean Training Loss:761.4485666
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '上映', '于是', '美国']
# Topic_1: ['主义', '国际', '组织', '社会', '国家', '革命', '马克思', '运动']
# Topic_2: ['香港', '作品', '动画', '电影', '日本', '制作', '系列', 'gundam']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '唱片', '歌手', '演出']
# Topic_4: ['食用', '可以', '植物', '地区', '使用', '常见', '制作', '食品']
# Topic_5: ['学名', '分布', '中国', '牠们', '台湾', '物种', '地区', '动物']
#
#
#
# Epoch  35	Mean Training Loss:760.4361248
#
# Topic_0: ['他们', '电影', '发现', '自己', '上映', '开始', '美国', '最后']
# Topic_1: ['主义', '社会主义', '国际', '社会', '马克思', '国家', '革命', '组织']
# Topic_2: ['作品', '香港', '电影', '动画', '系列', '制作', '日本', 'gundam']
# Topic_3: ['音乐', '专辑', '台湾', '乐团', '发行', '歌手', '唱片', '创作']
# Topic_4: ['食用', '可以', '植物', '食物', '地区', '食品', '主要', '一般']
# Topic_5: ['学名', '牠们', '分布', '台湾', '中国', '特征', '物种', '动物']
#
#
#
# Epoch  36	Mean Training Loss:761.6404728
#
# Topic_0: ['他们', '发现', '自己', '电影', '最后', '开始', '上映', '所有']
# Topic_1: ['主义', '社会', '国际', '社会主义', '国家', '组织', '工人', '马克思']
# Topic_2: ['香港', '作品', '动画', 'gundam', '系列', '战士', '机动', '电影']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '演唱会', '歌手', '唱片']
# Topic_4: ['食用', '植物', '可以', '地区', '食品', '常见', '蔬菜', '食物']
# Topic_5: ['学名', '分布', '牠们', '台湾', '中国', '黑色', '亚种', '特征']
#
#
#
# Epoch  37	Mean Training Loss:759.7440343
#
# Topic_0: ['他们', '电影', '自己', '发现', '开始', '美国', '最后', '上映']
# Topic_1: ['主义', '国际', '马克思', '社会主义', '社会', '组织', '革命', '工人']
# Topic_2: ['作品', '战士', '动画', 'gundam', '香港', '电影', '机动', '系列']
# Topic_3: ['专辑', '台湾', '音乐', '乐团', '发行', '演唱会', '唱片', '歌手']
# Topic_4: ['食用', '可以', '植物', '地区', '食物', '通常', '主要', '食品']
# Topic_5: ['学名', '物种', '牠们', '分布', '厘米', '中国', '地区', '特征']
#
#
#
# Epoch  38	Mean Training Loss:757.8879272
#
# Topic_0: ['他们', '自己', '发现', '电影', '美国', '最后', '上映', '决定']
# Topic_1: ['主义', '社会主义', '国际', '社会', '组织', '革命', '马克思', '国家']
# Topic_2: ['作品', 'gundam', '动画', '香港', '系列', '电影', '战士', '制作']
# Topic_3: ['专辑', '音乐', '乐团', '台湾', '发行', '演唱会', '唱片', '歌手']
# Topic_4: ['食用', '植物', '可以', '食物', '主要', '食品', '加入', '制作']
# Topic_5: ['牠们', '学名', '分布', '中国', '物种', '台湾', '黑色', '亚种']
#
#
#
# Epoch  39	Mean Training Loss:758.6518313
#
# Topic_0: ['他们', '发现', '自己', '电影', '美国', '上映', '开始', '最后']
# Topic_1: ['主义', '国际', '社会主义', '组织', '国家', '社会', '马克思', '工人']
# Topic_2: ['作品', '动画', '香港', '系列', '日本', '电影', '战士', 'gundam']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '创作', '演唱会', '歌手']
# Topic_4: ['地区', '食用', '可以', '制作', '植物', '主要', '一般', '常见']
# Topic_5: ['学名', '分布', '牠们', '中国', '台湾', '亚种', '黑色', '特征']
#
#
#
# Epoch  40	Mean Training Loss:758.2779758
#
# Topic_0: ['他们', '电影', '发现', '自己', '开始', '美国', '所有', '最后']
# Topic_1: ['主义', '马克思', '国际', '社会', '社会主义', '革命', '国家', '组织']
# Topic_2: ['香港', '作品', 'gundam', '动画', '系列', '机动', '战士', '电影']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '演唱会', '歌手', '创作']
# Topic_4: ['食用', '食品', '可以', '食物', '主要', '植物', '地区', '制作']
# Topic_5: ['学名', '分布', '牠们', '中国', '体长', '特征', '物种', '台湾']
#
#
#
# Epoch  41	Mean Training Loss:756.7315083
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '美国', '上映', '最后']
# Topic_1: ['主义', '国际', '马克思', '国家', '社会', '社会主义', '革命', '组织']
# Topic_2: ['作品', '香港', 'gundam', '动画', '机动', '战士', '系列', '电影']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '演唱会', '创作', '歌手']
# Topic_4: ['可以', '地区', '常见', '食用', '制作', '加入', '食品', '主要']
# Topic_5: ['学名', '牠们', '分布', '黑色', '特征', '中国', '台湾', '白色']
#
#
#
# Epoch  42	Mean Training Loss:757.1715760
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '美国', '于是', '上映']
# Topic_1: ['主义', '社会主义', '国际', '马克思', '组织', '社会', '国家', '革命']
# Topic_2: ['香港', '作品', '系列', '动画', 'gundam', '日本', '电影', '制作']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '唱片', '演唱会', '歌手']
# Topic_4: ['可以', '地区', '食物', '食用', '使用', '加入', '主要', '通常']
# Topic_5: ['学名', '牠们', '台湾', '分布', '黑色', '中国', '特征', '白色']
#
#
#
# Epoch  43	Mean Training Loss:757.1111093
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '最后', '所有', '来到']
# Topic_1: ['主义', '社会主义', '国际', '革命', '工人', '社会', '马克思', '组织']
# Topic_2: ['作品', '香港', '系列', '战士', 'gundam', '动画', '日本', '电影']
# Topic_3: ['专辑', '乐团', '台湾', '音乐', '发行', '唱片', '演唱会', '歌手']
# Topic_4: ['食用', '可以', '地区', '主要', '加入', '通常', '食物', '一般']
# Topic_5: ['学名', '分布', '牠们', '台湾', '黑色', '中国', '物种', '特征']
#
#
#
# Epoch  44	Mean Training Loss:756.6575018
#
# Topic_0: ['他们', '电影', '自己', '发现', '开始', '美国', '所有', '最后']
# Topic_1: ['主义', '国际', '社会主义', '马克思', '社会', '革命', '组织', '工人']
# Topic_2: ['作品', '香港', '动画', 'gundam', '机动', '战士', '电影', '日本']
# Topic_3: ['专辑', '台湾', '乐团', '音乐', '发行', '演唱会', '歌手', '唱片']
# Topic_4: ['食用', '可以', '使用', '食物', '制作', '蛋糕', '植物', '主要']
# Topic_5: ['学名', '分布', '中国', '台湾', '牠们', '黑色', '亚种', '地区']
#
#
#
# Epoch  45	Mean Training Loss:756.5175720
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '所有', '最后', '上映']
# Topic_1: ['主义', '国际', '社会', '马克思', '社会主义', '国家', '革命', '组织']
# Topic_2: ['香港', '作品', '动画', '战士', 'gundam', '电影', '制作', '日本']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '演唱会', '唱片', '歌手']
# Topic_4: ['食用', '可以', '植物', '常见', '加入', '中国', '制作', '地区']
# Topic_5: ['学名', '中国', '分布', '台湾', '特征', '白色', '分佈', '地区']
#
#
#
# Epoch  46	Mean Training Loss:755.8419996
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '所有', '美国', '最后']
# Topic_1: ['主义', '国际', '组织', '社会主义', '马克思', '社会', '革命', '国家']
# Topic_2: ['香港', '作品', '动画', '战士', '电影', 'gundam', '系列', '机动']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '演唱会', '唱片', '歌手']
# Topic_4: ['食用', '可以', '通常', '地区', '食物', '食品', '制作', '加入']
# Topic_5: ['学名', '黑色', '白色', '牠们', '体长', '厘米', '分布', '物种']
#
#
#
# Epoch  47	Mean Training Loss:756.0945081
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '美国', '所有', '之后']
# Topic_1: ['主义', '国际', '组织', '社会', '工人', '马克思', '社会主义', '阶级']
# Topic_2: ['作品', '香港', '战士', '动画', '日本', '制作', '剧场', '电影']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '演唱会', '唱片', '歌手']
# Topic_4: ['食用', '常见', '可以', '食品', '食物', '加入', '植物', '地区']
# Topic_5: ['学名', '分布', '牠们', '台湾', '黑色', '特征', '物种', '分佈']
#
#
#
# Epoch  48	Mean Training Loss:755.5695006
#
# Topic_0: ['他们', '自己', '电影', '发现', '美国', '上映', '开始', '决定']
# Topic_1: ['主义', '国际', '社会主义', '组织', '马克思', '社会', '工人', '国家']
# Topic_2: ['香港', '作品', '动画', 'gundam', '日本', '电影', '系列', '制作']
# Topic_3: ['专辑', '乐团', '台湾', '音乐', '发行', '演唱会', '唱片', '第一']
# Topic_4: ['食用', '可以', '食品', '通常', '制作', '常见', '蔬菜', '主要']
# Topic_5: ['学名', '分布', '牠们', '台湾', '黑色', '分佈', '物种', '中国']
#
#
#
# Epoch  49	Mean Training Loss:753.5078073
#
# Topic_0: ['他们', '发现', '电影', '自己', '美国', '开始', '最后', '上映']
# Topic_1: ['主义', '国际', '社会主义', '组织', '工人', '革命', '社会', '马克思']
# Topic_2: ['作品', 'gundam', '香港', '战士', '系列', '机动', '电影', '动画']
# Topic_3: ['专辑', '音乐', '台湾', '乐团', '发行', '唱片', '演唱会', '歌手']
# Topic_4: ['可以', '食用', '食品', '食物', '加入', '中国', '地区', '蔬菜']
# Topic_5: ['学名', '分布', '牠们', '白色', '黑色', '台湾', '中国', '特征']
#
#
#
# Epoch  50	Mean Training Loss:754.2265352
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '上映', '最后', '所有']
# Topic_1: ['主义', '国际', '社会主义', '马克思', '革命', '工人', '社会', '组织']
# Topic_2: ['香港', '作品', 'gundam', '系列', '胜出', '竞赛', '机动', '动画']
# Topic_3: ['专辑', '乐团', '台湾', '音乐', '发行', '唱片', '演唱会', '歌手']
# Topic_4: ['食用', '可以', '加入', '食物', '通常', '使用', '主要', '地区']
# Topic_5: ['学名', '分布', '黑色', '台湾', '牠们', '蛱蝶', '分佈', '中国']
#
#
#
# Epoch  51	Mean Training Loss:753.4277931
#
# Topic_0: ['发现', '他们', '电影', '自己', '开始', '上映', '美国', '最后']
# Topic_1: ['主义', '国际', '社会', '革命', '马克思', '社会主义', '组织', '工人']
# Topic_2: ['香港', '作品', '战士', 'gundam', '电影', '机动', '动画', '竞赛']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '演唱会', '唱片', '第一']
# Topic_4: ['可以', '食用', '植物', '加入', '制作', '主要', '地区', '使用']
# Topic_5: ['学名', '分布', '台湾', '黑色', '中国', '牠们', '特征', '白色']
#
#
#
# Epoch  52	Mean Training Loss:753.0387120
#
# Topic_0: ['他们', '发现', '自己', '电影', '开始', '所有', '最后', '美国']
# Topic_1: ['主义', '社会主义', '国际', '工人', '马克思', '社会', '革命', '组织']
# Topic_2: ['香港', '作品', 'gundam', '系列', '动画', '战士', '机动', '电影']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '发行', '唱片', '演唱会', '演出']
# Topic_4: ['食用', '可以', '地区', '食物', '常见', '主要', '通常', '使用']
# Topic_5: ['分布', '学名', '中国', '台湾', '黑色', '蛱蝶', '特征', '物种']
#
#
#
# Epoch  53	Mean Training Loss:753.9007403
#
# Topic_0: ['他们', '自己', '电影', '发现', '开始', '美国', '上映', '所有']
# Topic_1: ['主义', '国际', '社会', '社会主义', '马克思', '革命', '组织', '国家']
# Topic_2: ['作品', '香港', '动画', '赛事', 'gundam', '日本', '战士', '系列']
# Topic_3: ['专辑', '音乐', '乐团', '台湾', '发行', '唱片', '演唱会', '歌手']
# Topic_4: ['食用', '可以', '通常', '食品', '制成', '制作', '中国', '地区']
# Topic_5: ['学名', '分布', '中国', '黑色', '台湾', '蛱蝶', '白色', '特征']
#
#
#
# Epoch  54	Mean Training Loss:752.5033381
#
# Topic_0: ['他们', '自己', '发现', '电影', '美国', '开始', '上映', '所有']
# Topic_1: ['主义', '国际', '马克思', '社会主义', '组织', '社会', '国家', '工人']
# Topic_2: ['香港', '作品', '系列', 'gundam', '动画', '战士', '电影', '剧场']
# Topic_3: ['乐团', '专辑', '台湾', '音乐', '演唱会', '唱片', '发行', '演出']
# Topic_4: ['食用', '食品', '可以', '主要', '制作', '食物', '常见', '通常']
# Topic_5: ['学名', '白色', '分布', '黑色', '特征', '台湾', '厘米', '中国']
#
#
#
# Epoch  55	Mean Training Loss:752.5790025
#
# Topic_0: ['他们', '电影', '发现', '自己', '开始', '所有', '最后', '美国']
# Topic_1: ['主义', '国际', '社会主义', '工人', '革命', '社会', '组织', '马克思']
# Topic_2: ['香港', 'gundam', '作品', '战士', '机动', '系列', '动画', '日本']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '演唱会', '发行', '唱片', '歌手']
# Topic_4: ['食用', '可以', '通常', '常见', '使用', '食物', '加入', '地区']
# Topic_5: ['分布', '学名', '台湾', '黑色', '特征', '白色', '牠们', '地区']
#
#
#
# Epoch  56	Mean Training Loss:752.8011563
#
# Topic_0: ['发现', '他们', '自己', '电影', '开始', '决定', '所有', '上映']
# Topic_1: ['主义', '国际', '社会', '社会主义', '组织', '革命', '马克思', '工人']
# Topic_2: ['香港', '作品', '动画', '系列', '赛事', '战士', '剧场', '竞赛']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '唱片', '发行', '演唱会', '演出']
# Topic_4: ['食用', '植物', '食物', '食品', '可以', '通常', '主要', '一般']
# Topic_5: ['学名', '分布', '黑色', '牠们', '中国', '凤蝶', '特征', '白色']
#
#
#
# Epoch  57	Mean Training Loss:753.0975265
#
# Topic_0: ['他们', '自己', '发现', '电影', '开始', '美国', '所有', '决定']
# Topic_1: ['主义', '国际', '社会主义', '工人', '组织', '社会', '马克思', '革命']
# Topic_2: ['香港', 'gundam', '作品', '机动', '战士', '动画', '系列', '赛事']
# Topic_3: ['专辑', '乐团', '音乐', '台湾', '演唱会', '发行', '唱片', '第一']
# Topic_4: ['可以', '食用', '主要', '常见', '加入', '制作', '地区', '通常']
# Topic_5: ['学名', '分布', '黑色', '中国', '蛱蝶', '台湾', '地区', '白色']
#
#
#
# Early stopping at Epoch 57. Reverting to Epoch 54

# %%
print('Computing metrics for Chinese... BOW')
compute(tm_zh, train_dataset_zh, './output_task1_BOW_zh_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for Chinese... BOW
# 0 3 0 1 4 2
# f1_macro = 0.5650677911750467
# f1_micro = 0.6476566354218056
# acc = 0.6476566354218056
# ars = 0.41295399098946156
# --------------------------------------------------

# %%
print('Computing metrics for Chinese... BOW, zh2en')
compute(tm_zh, train_dataset_en, './output_task1_BOW_zh_zh2en_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for Chinese... BOW, zh2en
# 5 3 0 1 4 2
# f1_macro = 0.22986404299182628
# f1_micro = 0.2611609164176401
# acc = 0.2611609164176401
# ars = 0.021097720141060483
# --------------------------------------------------

# %%
print('Computing metrics for English... BOW, en2zh')
compute(tm_en, train_dataset_zh, './output_task1_BOW_zh_en2zh_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for English... BOW, en2zh
# 3 1 0 1 1 3
# f1_macro = 0.12706910645802394
# f1_micro = 0.23058707449432658
# acc = 0.23058707449432658
# ars = 0.003997926122177804
# --------------------------------------------------

# %%
tm_en = GTM(
    train_dataset_en,
    n_topics=6,
    doc_topic_prior='dirichlet',
    update_prior=False,
    encoder_hidden_layers=[256],
    decoder_hidden_layers=[256],
    learning_rate=1e-3,
    num_workers=0,
    patience=3,
    num_epochs=1000,
    encoder_input='embeddings',
    ckpt_folder='./ckpt_task1_redo_en_emb',
    # ckpt='./ckpt_task1_redo_en_emb/best_model.ckpt',
)
# Out:
# Epoch   1	Mean Training Loss:1430.8183728
#
# Topic_0: ['film', 'state', 'release', 'include', 'album', 'record', 'year', 'group']
# Topic_1: ['state', 'release', 'film', 'album', 'use', 'group', 'year', 'know']
# Topic_2: ['film', 'state', 'use', 'new', 'release', 'album', 'know', 'include']
# Topic_3: ['release', 'album', 'year', 'film', 'new', 'state', 'include', 'know']
# Topic_4: ['release', 'year', 'album', 'new', 'film', 'state', 'know', 'use']
# Topic_5: ['state', 'album', 'film', 'release', 'know', 'year', 'record', 'new']
#
#
#
# Epoch   2	Mean Training Loss:1389.9713526
#
# Topic_0: ['include', 'film', 'make', 'use', 'new', 'know', 'year', 'state']
# Topic_1: ['release', 'state', 'film', 'know', 'include', 'use', 'year', 'new']
# Topic_2: ['new', 'release', 'know', 'include', 'album', 'year', 'film', 'use']
# Topic_3: ['release', 'album', 'record', 'new', 'year', 'group', 'include', 'know']
# Topic_4: ['release', 'album', 'year', 'new', 'right', 'film', 'include', 'group']
# Topic_5: ['film', 'know', 'use', 'new', 'make', 'year', 'release', 'state']
#
#
#
# Epoch   3	Mean Training Loss:1358.7485500
#
# Topic_0: ['specie', 'bird', 'chicken', 'use', 'white', 'breed', 'food', 'make']
# Topic_1: ['film', 'use', 'chinese', 'state', 'year', 'include', 'make', 'new']
# Topic_2: ['release', 'film', 'album', 'year', 'new', 'record', 'group', 'music']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'feature']
# Topic_4: ['woman', 'right', 'child', 'traffic', 'law', 'government', 'victim', 'sex']
# Topic_5: ['bird', 'specie', 'food', 'chicken', 'white', 'restaurant', 'use', 'make']
#
#
#
# Epoch   4	Mean Training Loss:1324.3797576
#
# Topic_0: ['specie', 'bird', 'breed', 'white', 'genus', 'chicken', 'tail', 'parrot']
# Topic_1: ['chinese', 'shrine', 'temple', 'century', 'japanese', 'dynasty', 'state', 'use']
# Topic_2: ['release', 'album', 'film', 'record', 'music', 'hop', 'hip', 'career']
# Topic_3: ['album', 'release', 'record', 'hop', 'group', 'hip', 'music', 'song']
# Topic_4: ['woman', 'government', 'law', 'right', 'traffic', 'sex', 'victim', 'child']
# Topic_5: ['food', 'restaurant', 'chicken', 'company', 'bird', 'chain', 'specie', 'cream']
#
#
#
# Epoch   5	Mean Training Loss:1306.5108075
#
# Topic_0: ['bird', 'specie', 'black', 'white', 'wing', 'eagle', 'long', 'genus']
# Topic_1: ['chinese', 'shrine', 'temple', 'god', 'school', 'dynasty', 'japanese', 'life']
# Topic_2: ['release', 'album', 'film', 'record', 'hop', 'music', 'hip', 'group']
# Topic_3: ['album', 'release', 'record', 'music', 'single', 'hop', 'group', 'hip']
# Topic_4: ['traffic', 'government', 'woman', 'right', 'law', 'victim', 'sex', 'child']
# Topic_5: ['restaurant', 'food', 'chicken', 'company', 'chain', 'cream', 'serve', 'ice']
#
#
#
# Epoch   6	Mean Training Loss:1300.4588193
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'black', 'tail', 'eagle', 'wing']
# Topic_1: ['chinese', 'shrine', 'temple', 'god', 'japanese', 'know', 'dynasty', 'use']
# Topic_2: ['release', 'album', 'film', 'hop', 'hip', 'record', 'group', 'music']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'group', 'song']
# Topic_4: ['traffic', 'right', 'victim', 'government', 'sex', 'law', 'woman', 'sexual']
# Topic_5: ['restaurant', 'sandwich', 'food', 'chicken', 'product', 'company', 'cheese', 'pizza']
#
#
#
# Epoch   7	Mean Training Loss:1296.4770148
#
# Topic_0: ['specie', 'bird', 'white', 'breed', 'genus', 'black', 'male', 'tail']
# Topic_1: ['chinese', 'shrine', 'temple', 'dynasty', 'school', 'kami', 'text', 'century']
# Topic_2: ['release', 'album', 'music', 'record', 'film', 'hop', 'hip', 'feature']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'song', 'hop', 'new']
# Topic_4: ['traffic', 'woman', 'sex', 'law', 'victim', 'child', 'right', 'government']
# Topic_5: ['chicken', 'food', 'restaurant', 'sandwich', 'fry', 'cheese', 'company', 'cream']
#
#
#
# Epoch   8	Mean Training Loss:1292.3538159
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'breed', 'black', 'tail', 'eagle']
# Topic_1: ['chinese', 'shrine', 'temple', 'dynasty', 'shinto', 'know', 'god', 'japanese']
# Topic_2: ['release', 'album', 'music', 'record', 'hop', 'hip', 'single', 'feature']
# Topic_3: ['album', 'release', 'record', 'music', 'single', 'hop', 'feature', 'hip']
# Topic_4: ['traffic', 'sex', 'victim', 'law', 'government', 'right', 'woman', 'child']
# Topic_5: ['restaurant', 'pizza', 'chicken', 'food', 'cheese', 'cream', 'fry', 'sandwich']
#
#
#
# Epoch   9	Mean Training Loss:1289.2704627
#
# Topic_0: ['specie', 'bird', 'white', 'black', 'eagle', 'genus', 'male', 'tail']
# Topic_1: ['chinese', 'shrine', 'temple', 'dynasty', 'god', 'text', 'school', 'century']
# Topic_2: ['release', 'album', 'record', 'hop', 'hip', 'music', 'rapper', 'rap']
# Topic_3: ['release', 'album', 'record', 'music', 'hop', 'hip', 'song', 'group']
# Topic_4: ['traffic', 'sex', 'law', 'right', 'government', 'victim', 'woman', 'sexual']
# Topic_5: ['sandwich', 'food', 'chicken', 'dish', 'bread', 'fry', 'cheese', 'restaurant']
#
#
#
# Epoch  10	Mean Training Loss:1287.5999424
#
# Topic_0: ['specie', 'bird', 'black', 'genus', 'white', 'eagle', 'tail', 'parrot']
# Topic_1: ['chinese', 'shrine', 'school', 'text', 'dynasty', 'scholar', 'god', 'temple']
# Topic_2: ['album', 'release', 'record', 'song', 'group', 'music', 'single', 'hop']
# Topic_3: ['album', 'release', 'record', 'group', 'music', 'song', 'single', 'feature']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'law', 'child', 'woman', 'right']
# Topic_5: ['sandwich', 'fry', 'cheese', 'food', 'dish', 'chicken', 'serve', 'pizza']
#
#
#
# Epoch  11	Mean Training Loss:1287.1339926
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'tail', 'black', 'breed', 'male']
# Topic_1: ['chinese', 'shrine', 'dynasty', 'temple', 'century', 'shinto', 'kami', 'text']
# Topic_2: ['album', 'release', 'record', 'hop', 'music', 'group', 'hip', 'song']
# Topic_3: ['album', 'release', 'record', 'music', 'song', 'hop', 'group', 'hip']
# Topic_4: ['traffic', 'sex', 'victim', 'law', 'government', 'sexual', 'child', 'right']
# Topic_5: ['sandwich', 'cheese', 'chicken', 'pizza', 'serve', 'fry', 'food', 'dish']
#
#
#
# Epoch  12	Mean Training Loss:1285.5492268
#
# Topic_0: ['specie', 'bird', 'white', 'black', 'genus', 'female', 'tail', 'male']
# Topic_1: ['chinese', 'shrine', 'school', 'dynasty', 'temple', 'text', 'know', 'confucius']
# Topic_2: ['album', 'release', 'record', 'music', 'song', 'hop', 'group', 'feature']
# Topic_3: ['album', 'release', 'record', 'music', 'song', 'group', 'single', 'hop']
# Topic_4: ['traffic', 'sex', 'government', 'victim', 'law', 'child', 'sexual', 'woman']
# Topic_5: ['sandwich', 'cheese', 'fry', 'food', 'dish', 'make', 'serve', 'bread']
#
#
#
# Epoch  13	Mean Training Loss:1284.1265407
#
# Topic_0: ['specie', 'bird', 'genus', 'black', 'white', 'tail', 'male', 'female']
# Topic_1: ['chinese', 'shrine', 'dynasty', 'text', 'school', 'temple', 'know', 'god']
# Topic_2: ['album', 'release', 'record', 'song', 'music', 'group', 'hop', 'hip']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'song']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'law', 'sexual', 'trafficking', 'woman']
# Topic_5: ['sandwich', 'cheese', 'serve', 'fry', 'make', 'chicken', 'food', 'pizza']
#
#
#
# Epoch  14	Mean Training Loss:1283.0792226
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'tail', 'black', 'owl', 'male']
# Topic_1: ['chinese', 'shrine', 'school', 'dynasty', 'temple', 'text', 'scholar', 'taoist']
# Topic_2: ['release', 'album', 'record', 'music', 'hop', 'hip', 'single', 'group']
# Topic_3: ['album', 'release', 'record', 'music', 'single', 'hop', 'group', 'song']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'law', 'child', 'trafficking', 'human']
# Topic_5: ['fry', 'cheese', 'dish', 'food', 'pizza', 'use', 'sandwich', 'serve']
#
#
#
# Epoch  15	Mean Training Loss:1281.6350214
#
# Topic_0: ['specie', 'bird', 'owl', 'black', 'white', 'genus', 'eagle', 'tail']
# Topic_1: ['chinese', 'school', 'dynasty', 'shrine', 'know', 'yang', 'temple', 'text']
# Topic_2: ['album', 'release', 'record', 'group', 'hop', 'hip', 'feature', 'music']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'song', 'single']
# Topic_4: ['traffic', 'victim', 'government', 'sex', 'law', 'trafficking', 'child', 'country']
# Topic_5: ['dish', 'fry', 'sandwich', 'chicken', 'cheese', 'make', 'food', 'serve']
#
#
#
# Epoch  16	Mean Training Loss:1279.9704540
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'tail', 'forest', 'black', 'owl']
# Topic_1: ['chinese', 'dynasty', 'school', 'temple', 'confucius', 'text', 'confucian', 'taoist']
# Topic_2: ['album', 'release', 'record', 'music', 'hop', 'song', 'hip', 'single']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'single']
# Topic_4: ['traffic', 'victim', 'government', 'sex', 'law', 'trafficking', 'child', 'country']
# Topic_5: ['cheese', 'dish', 'pizza', 'make', 'use', 'serve', 'sandwich', 'fry']
#
#
#
# Epoch  17	Mean Training Loss:1279.1558669
#
# Topic_0: ['specie', 'bird', 'white', 'tail', 'genus', 'black', 'wing', 'eagle']
# Topic_1: ['chinese', 'dynasty', 'text', 'century', 'school', 'religion', 'scholar', 'classic']
# Topic_2: ['album', 'release', 'record', 'music', 'single', 'hip', 'hop', 'group']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'song', 'hip', 'single']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'trafficking', 'child', 'sexual', 'law']
# Topic_5: ['make', 'dish', 'serve', 'cheese', 'use', 'fry', 'sandwich', 'meat']
#
#
#
# Epoch  18	Mean Training Loss:1279.5412439
#
# Topic_0: ['specie', 'bird', 'white', 'black', 'tail', 'genus', 'male', 'range']
# Topic_1: ['chinese', 'dynasty', 'text', 'confucius', 'confucian', 'temple', 'classic', 'china']
# Topic_2: ['album', 'release', 'record', 'music', 'hop', 'hip', 'song', 'group']
# Topic_3: ['album', 'release', 'record', 'hop', 'music', 'hip', 'single', 'group']
# Topic_4: ['traffic', 'victim', 'government', 'sex', 'law', 'trafficking', 'child', 'sexual']
# Topic_5: ['make', 'sandwich', 'food', 'dish', 'fry', 'cheese', 'use', 'bread']
#
#
#
# Epoch  19	Mean Training Loss:1277.7026131
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'black', 'tail', 'wing', 'owl']
# Topic_1: ['chinese', 'dynasty', 'text', 'confucius', 'school', 'know', 'master', 'classic']
# Topic_2: ['album', 'release', 'record', 'music', 'hop', 'hip', 'song', 'group']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'song']
# Topic_4: ['traffic', 'victim', 'government', 'trafficking', 'sex', 'law', 'child', 'labor']
# Topic_5: ['cheese', 'food', 'dish', 'use', 'sandwich', 'make', 'fry', 'chicken']
#
#
#
# Epoch  20	Mean Training Loss:1276.6053467
#
# Topic_0: ['specie', 'bird', 'black', 'genus', 'wing', 'white', 'subspecies', 'habitat']
# Topic_1: ['chinese', 'dynasty', 'confucian', 'confucius', 'school', 'text', 'taoist', 'know']
# Topic_2: ['album', 'release', 'record', 'music', 'group', 'song', 'single', 'hop']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'song', 'single', 'hop']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'trafficking', 'child', 'law', 'labor']
# Topic_5: ['sandwich', 'cheese', 'make', 'dish', 'use', 'food', 'pizza', 'serve']
#
#
#
# Epoch  21	Mean Training Loss:1277.0531994
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'black', 'male', 'wing', 'female']
# Topic_1: ['chinese', 'school', 'dynasty', 'pinyin', 'taoist', 'confucius', 'text', 'confucian']
# Topic_2: ['release', 'album', 'record', 'music', 'group', 'song', 'single', 'hip']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'single', 'rapper', 'song']
# Topic_4: ['traffic', 'victim', 'sex', 'government', 'child', 'trafficking', 'law', 'sexual']
# Topic_5: ['cheese', 'sandwich', 'dish', 'make', 'food', 'serve', 'use', 'fry']
#
#
#
# Epoch  22	Mean Training Loss:1276.1279935
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'black', 'long', 'parrot', 'forest']
# Topic_1: ['chinese', 'dynasty', 'text', 'confucius', 'confucian', 'school', 'pinyin', 'taoist']
# Topic_2: ['album', 'release', 'record', 'music', 'hip', 'hop', 'group', 'single']
# Topic_3: ['album', 'release', 'record', 'group', 'music', 'single', 'hop', 'song']
# Topic_4: ['traffic', 'victim', 'trafficking', 'government', 'sex', 'law', 'child', 'labor']
# Topic_5: ['sandwich', 'cheese', 'make', 'food', 'use', 'bread', 'pizza', 'dish']
#
#
#
# Epoch  23	Mean Training Loss:1275.0518866
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'eagle', 'black', 'tail', 'parrot']
# Topic_1: ['chinese', 'dynasty', 'classic', 'confucius', 'text', 'confucian', 'scholar', 'school']
# Topic_2: ['release', 'album', 'record', 'music', 'group', 'hop', 'rapper', 'hip']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'group', 'single']
# Topic_4: ['traffic', 'victim', 'government', 'trafficking', 'child', 'sex', 'labor', 'sexual']
# Topic_5: ['fry', 'make', 'dish', 'cheese', 'sandwich', 'serve', 'pizza', 'use']
#
#
#
# Epoch  24	Mean Training Loss:1274.2473201
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'black', 'wing', 'tail', 'female']
# Topic_1: ['chinese', 'dynasty', 'confucius', 'confucian', 'classic', 'text', 'school', 'pinyin']
# Topic_2: ['album', 'release', 'record', 'hop', 'hip', 'group', 'music', 'song']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'single']
# Topic_4: ['traffic', 'victim', 'child', 'sex', 'government', 'trafficking', 'law', 'sexual']
# Topic_5: ['make', 'fry', 'serve', 'cheese', 'use', 'sandwich', 'dish', 'food']
#
#
#
# Epoch  25	Mean Training Loss:1272.7571545
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'black', 'female', 'tail', 'long']
# Topic_1: ['chinese', 'dynasty', 'text', 'school', 'tao', 'classic', 'pinyin', 'taoist']
# Topic_2: ['release', 'album', 'record', 'hip', 'hop', 'song', 'group', 'music']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'single', 'song']
# Topic_4: ['traffic', 'victim', 'government', 'child', 'sex', 'trafficking', 'law', 'labor']
# Topic_5: ['cheese', 'sandwich', 'food', 'make', 'use', 'dish', 'pizza', 'bread']
#
#
#
# Epoch  26	Mean Training Loss:1274.8656447
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'owl', 'forest', 'black', 'wing']
# Topic_1: ['chinese', 'dynasty', 'confucius', 'text', 'classic', 'tao', 'taoist', 'school']
# Topic_2: ['album', 'release', 'record', 'music', 'hop', 'group', 'song', 'hip']
# Topic_3: ['album', 'release', 'record', 'music', 'hop', 'hip', 'single', 'group']
# Topic_4: ['traffic', 'victim', 'government', 'sex', 'trafficking', 'child', 'law', 'force']
# Topic_5: ['sandwich', 'make', 'cheese', 'use', 'fry', 'food', 'serve', 'bread']
#
#
#
# Epoch  27	Mean Training Loss:1273.1528733
#
# Topic_0: ['specie', 'bird', 'white', 'genus', 'black', 'parrot', 'tail', 'wing']
# Topic_1: ['chinese', 'dynasty', 'master', 'text', 'school', 'han', 'taoism', 'tao']
# Topic_2: ['album', 'release', 'record', 'music', 'hip', 'hop', 'group', 'song']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'single']
# Topic_4: ['traffic', 'victim', 'government', 'child', 'trafficking', 'labor', 'law', 'sex']
# Topic_5: ['dish', 'food', 'cheese', 'use', 'make', 'sandwich', 'serve', 'pizza']
#
#
#
# Epoch  28	Mean Training Loss:1273.2103010
#
# Topic_0: ['specie', 'bird', 'genus', 'white', 'tail', 'parrot', 'wing', 'black']
# Topic_1: ['chinese', 'dynasty', 'text', 'master', 'confucius', 'zhang', 'classic', 'know']
# Topic_2: ['album', 'release', 'record', 'hop', 'hip', 'group', 'single', 'song']
# Topic_3: ['album', 'release', 'record', 'music', 'group', 'hop', 'hip', 'song']
# Topic_4: ['traffic', 'victim', 'government', 'sex', 'trafficking', 'child', 'sexual', 'force']
# Topic_5: ['sandwich', 'cheese', 'dish', 'make', 'serve', 'pizza', 'meat', 'food']
#
#
#
# Early stopping at Epoch 28. Reverting to Epoch 25

# %%
print('Computing metrics for English... Embeddings')
compute(tm_en, train_dataset_en, './output_task1_redo_en_emb')
# Out:
# Computing metrics for English... Embeddings
# 2 4 0 1 3 5
# f1_macro = 0.8803765050948384
# f1_micro = 0.8813728153581454
# acc = 0.8813728153581454
# ars = 0.7483313628795738
# --------------------------------------------------

# %%
tm_zh = GTM(
    train_dataset_zh,
    n_topics=6,
    doc_topic_prior='dirichlet',
    update_prior=False,
    encoder_hidden_layers=[256],
    decoder_hidden_layers=[256],
    learning_rate=1e-3,
    num_workers=0,
    patience=3,
    num_epochs=1000,
    encoder_input='embeddings',
    ckpt_folder='./ckpt_task1_redo_zh_emb',
    # ckpt='./ckpt_task1_redo_zh_emb/best_model.ckpt',
)
# Out:
# Epoch   1	Mean Training Loss:859.0559301
#
# Topic_0: ['台湾', '音乐', '大学', '电影', '中国', '美国', '主义', '开始']
# Topic_1: ['台湾', '美国', '大学', '电影', '中国', '音乐', '成为', '第一']
# Topic_2: ['台湾', '电影', '中国', '美国', '音乐', '大学', '年月', '开始']
# Topic_3: ['台湾', '中国', '大学', '电影', '音乐', '美国', '第一', '开始']
# Topic_4: ['台湾', '电影', '中国', '美国', '大学', '音乐', '开始', '第一']
# Topic_5: ['台湾', '电影', '音乐', '中国', '美国', '开始', '大学', '自己']
#
#
#
# Epoch   2	Mean Training Loss:833.9036723
#
# Topic_0: ['台湾', '电影', '中国', '美国', '音乐', '英语', '他们', '大学']
# Topic_1: ['台湾', '电影', '美国', '中国', '他们', '第一', '大学', '成为']
# Topic_2: ['台湾', '中国', '电影', '美国', '音乐', '第一', '大学', '日本']
# Topic_3: ['台湾', '中国', '音乐', '大学', '电影', '美国', '第一', '专辑']
# Topic_4: ['台湾', '中国', '电影', '美国', '大学', '音乐', '第一', '日本']
# Topic_5: ['台湾', '电影', '美国', '中国', '他们', '开始', '音乐', '自己']
#
#
#
# Epoch   3	Mean Training Loss:821.9422477
#
# Topic_0: ['电影', '学名', '他们', '发现', '自己', '美国', '上映', '英语']
# Topic_1: ['电影', '他们', '美国', '自己', '英语', '中国', '发现', '学名']
# Topic_2: ['台湾', '中国', '大学', '年月', '音乐', '第一', '香港', '运动']
# Topic_3: ['台湾', '大学', '音乐', '中国', '乐团', '专辑', '担任', '节目']
# Topic_4: ['台湾', '中国', '大学', '音乐', '第一', '香港', '年月', '专辑']
# Topic_5: ['电影', '他们', '自己', '发现', '美国', '英语', '上映', '故事']
#
#
#
# Epoch   4	Mean Training Loss:811.0833303
#
# Topic_0: ['电影', '发现', '他们', '学名', '上映', '美国', '自己', '英语']
# Topic_1: ['电影', '美国', '他们', '英语', '自己', '发现', '上映', '中国']
# Topic_2: ['台湾', '大学', '中国', '音乐', '年月', '美国', '运动', '政府']
# Topic_3: ['台湾', '音乐', '大学', '专辑', '中国', '担任', '歌手', '唱片']
# Topic_4: ['台湾', '大学', '音乐', '中国', '专辑', '香港', '美国', '第一']
# Topic_5: ['电影', '他们', '自己', '上映', '发现', '美国', '英语', '故事']
#
#
#
# Epoch   5	Mean Training Loss:807.0219485
#
# Topic_0: ['学名', '电影', '牠们', '分布', '物种', '发现', '中国', '他们']
# Topic_1: ['他们', '电影', '美国', '发现', '自己', '中国', '主要', '上映']
# Topic_2: ['大学', '中国', '台湾', '年月', '运动', '革命', '主义', '政府']
# Topic_3: ['台湾', '音乐', '大学', '专辑', '歌手', '担任', '乐团', '中国']
# Topic_4: ['台湾', '大学', '中国', '音乐', '专辑', '担任', '年月', '中华']
# Topic_5: ['电影', '他们', '自己', '上映', '发现', '故事', '动画', '美国']
#
#
#
# Epoch   6	Mean Training Loss:796.5568986
#
# Topic_0: ['学名', '分布', '中国', '物种', '牠们', '地区', '动物', '台湾']
# Topic_1: ['他们', '穆斯林', '发现', '美国', '中国', '认为', '伊斯兰教', '学名']
# Topic_2: ['台湾', '中国', '年月', '大学', '革命', '政府', '主义', '运动']
# Topic_3: ['音乐', '台湾', '乐团', '专辑', '歌手', '创作', '大学', '演出']
# Topic_4: ['台湾', '音乐', '大学', '中国', '专辑', '歌手', '担任', '第一']
# Topic_5: ['电影', '上映', '动画', '自己', '他们', '故事', '美国', '剧情']
#
#
#
# Epoch   7	Mean Training Loss:787.9981709
#
# Topic_0: ['学名', '分布', '物种', '中国', '台湾', '地区', '牠们', '主要']
# Topic_1: ['学名', '他们', '穆斯林', '地区', '阿拉伯语', '伊斯兰教', '认为', '其他']
# Topic_2: ['大学', '中国', '台湾', '主义', '运动', '年月', '组织', '政府']
# Topic_3: ['音乐', '台湾', '专辑', '乐团', '发行', '唱片', '歌手', '创作']
# Topic_4: ['台湾', '音乐', '大学', '中国', '专辑', '担任', '歌手', '第一']
# Topic_5: ['电影', '动画', '上映', '他们', '自己', '美国', '发现', '剧情']
#
#
#
# Epoch   8	Mean Training Loss:784.4457144
#
# Topic_0: ['学名', '中国', '分布', '台湾', '牠们', '地区', '物种', '动物']
# Topic_1: ['学名', '穆斯林', '宗教', '伊斯兰教', '他们', '伊斯兰', '分布', '地区']
# Topic_2: ['中国', '运动', '主义', '革命', '台湾', '大学', '年月', '政府']
# Topic_3: ['音乐', '台湾', '专辑', '歌手', '乐团', '节目', '唱片', '发行']
# Topic_4: ['台湾', '音乐', '大学', '中国', '担任', '专辑', '国立', '歌手']
# Topic_5: ['电影', '上映', '他们', '美国', '动画', '剧情', '发现', '自己']
#
#
#
# Epoch   9	Mean Training Loss:780.8738557
#
# Topic_0: ['学名', '中国', '台湾', '牠们', '分布', '物种', '地区', '动物']
# Topic_1: ['学名', '穆斯林', '伊斯兰教', '阿拉伯语', '伊斯兰', '他们', '教会', '地区']
# Topic_2: ['主义', '中国', '台湾', '年月', '运动', '政府', '组织', '政治']
# Topic_3: ['台湾', '音乐', '专辑', '唱片', '乐团', '歌手', '发行', '电影']
# Topic_4: ['台湾', '音乐', '大学', '中国', '专辑', '乐团', '担任', '中华']
# Topic_5: ['电影', '他们', '自己', '上映', '发现', '剧情', '动画', '故事']
#
#
#
# Epoch  10	Mean Training Loss:778.8660351
#
# Topic_0: ['学名', '台湾', '中国', '分布', '牠们', '物种', '动物', '地区']
# Topic_1: ['学名', '穆斯林', '教会', '伊斯兰', '伊斯兰教', '阿拉伯语', '宗教', '基督教']
# Topic_2: ['主义', '台湾', '中国', '革命', '政府', '政治', '大学', '组织']
# Topic_3: ['音乐', '台湾', '专辑', '乐团', '歌手', '节目', '唱片', '发行']
# Topic_4: ['台湾', '音乐', '大学', '中国', '乐团', '担任', '专辑', '国立']
# Topic_5: ['电影', '他们', '上映', '自己', '美国', '动画', '剧情', '发现']
#
#
#
# Epoch  11	Mean Training Loss:777.7460289
#
# Topic_0: ['学名', '台湾', '分布', '中国', '物种', '牠们', '地区', '动物']
# Topic_1: ['穆斯林', '学名', '伊斯兰教', '伊斯兰', '阿拉伯语', '教会', '古兰经', '他们']
# Topic_2: ['中国', '台湾', '主义', '政府', '运动', '革命', '年月', '中华']
# Topic_3: ['音乐', '台湾', '专辑', '歌手', '节目', '发行', '唱片', '乐团']
# Topic_4: ['音乐', '台湾', '大学', '中国', '乐团', '国立', '学校', '担任']
# Topic_5: ['电影', '他们', '上映', '美国', '自己', '故事', '动画', '发现']
#
#
#
# Epoch  12	Mean Training Loss:776.5456531
#
# Topic_0: ['学名', '台湾', '分布', '中国', '物种', '牠们', '黑色', '地区']
# Topic_1: ['学名', '穆斯林', '伊斯兰教', '伊斯兰', '阿拉伯语', '古兰经', '教会', '基督教']
# Topic_2: ['台湾', '中国', '主义', '中华', '运动', '年月', '革命', '政治']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '乐团', '个人']
# Topic_4: ['音乐', '大学', '台湾', '中国', '国立', '乐团', '学校', '担任']
# Topic_5: ['电影', '他们', '上映', '自己', '发现', '美国', '剧情', '动画']
#
#
#
# Epoch  13	Mean Training Loss:775.1955835
#
# Topic_0: ['学名', '台湾', '分布', '中国', '地区', '牠们', '物种', '动物']
# Topic_1: ['穆斯林', '学名', '阿拉伯语', '伊斯兰教', '伊斯兰', '古兰经', '地区', '不同']
# Topic_2: ['台湾', '中国', '主义', '中华', '运动', '政府', '革命', '年月']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '唱片', '乐团']
# Topic_4: ['音乐', '台湾', '大学', '中国', '乐团', '学院', '国立', '担任']
# Topic_5: ['电影', '上映', '他们', '自己', '美国', '发现', '动画', '剧情']
#
#
#
# Epoch  14	Mean Training Loss:773.2594777
#
# Topic_0: ['学名', '台湾', '分布', '中国', '物种', '牠们', '地区', '动物']
# Topic_1: ['穆斯林', '学名', '古兰经', '阿拉伯语', '伊斯兰教', '伊斯兰', '基督教', '阿拉伯']
# Topic_2: ['台湾', '主义', '运动', '中国', '革命', '中华', '组织', '人民']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '唱片', '乐团']
# Topic_4: ['音乐', '台湾', '大学', '中国', '乐团', '学院', '学校', '国立']
# Topic_5: ['电影', '他们', '上映', '自己', '发现', '美国', '动画', '剧情']
#
#
#
# Epoch  15	Mean Training Loss:772.4628749
#
# Topic_0: ['学名', '台湾', '分布', '中国', '牠们', '物种', '地区', '黑色']
# Topic_1: ['穆斯林', '伊斯兰', '伊斯兰教', '学名', '阿拉伯语', '古兰经', '基督教', '教会']
# Topic_2: ['主义', '台湾', '中国', '运动', '中华', '革命', '社会', '社会主义']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '个人', '唱片', '节目']
# Topic_4: ['大学', '音乐', '台湾', '学院', '中国', '学校', '国立', '乐团']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '故事', '开始']
#
#
#
# Epoch  16	Mean Training Loss:772.8376557
#
# Topic_0: ['学名', '分布', '台湾', '中国', '牠们', '物种', '地区', '动物']
# Topic_1: ['阿拉伯语', '伊斯兰教', '学名', '穆斯林', '古兰经', '基督教', '伊斯兰', '教会']
# Topic_2: ['台湾', '主义', '运动', '中国', '政治', '革命', '社会', '组织']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '个人', '唱片']
# Topic_4: ['音乐', '大学', '中国', '台湾', '学院', '乐团', '学校', '国立']
# Topic_5: ['电影', '他们', '上映', '发现', '自己', '美国', '动画', '英语']
#
#
#
# Epoch  17	Mean Training Loss:772.0425323
#
# Topic_0: ['学名', '分布', '台湾', '中国', '牠们', '物种', '地区', '黑色']
# Topic_1: ['穆斯林', '阿拉伯语', '伊斯兰教', '基督教', '教会', '古兰经', '伊斯兰', '阿拉伯']
# Topic_2: ['主义', '中国', '台湾', '革命', '组织', '运动', '民主', '社会']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '唱片', '节目', '乐团']
# Topic_4: ['音乐', '大学', '学院', '中国', '台湾', '学校', '乐团', '北京']
# Topic_5: ['电影', '他们', '自己', '发现', '上映', '美国', '英语', '动画']
#
#
#
# Epoch  18	Mean Training Loss:772.3532108
#
# Topic_0: ['学名', '分布', '中国', '台湾', '物种', '牠们', '动物', '地区']
# Topic_1: ['阿拉伯语', '伊斯兰教', '穆斯林', '古兰经', '基督教', '学名', '宗教', '真主']
# Topic_2: ['台湾', '主义', '中国', '国际', '组织', '革命', '运动', '社会']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '节目', '唱片', '个人']
# Topic_4: ['大学', '音乐', '中国', '学院', '台湾', '学校', '国立', '乐团']
# Topic_5: ['电影', '他们', '自己', '上映', '发现', '美国', '英语', '剧情']
#
#
#
# Epoch  19	Mean Training Loss:770.6871200
#
# Topic_0: ['学名', '分布', '台湾', '物种', '中国', '牠们', '地区', '黑色']
# Topic_1: ['伊斯兰教', '阿拉伯语', '古兰经', '穆斯林', '伊斯兰', '真主', '宗教', '基督教']
# Topic_2: ['主义', '台湾', '社会', '革命', '运动', '中国', '国际', '社会主义']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '节目', '乐团', '唱片']
# Topic_4: ['大学', '音乐', '学院', '中国', '台湾', '学校', '北京', '国立']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '英语', '开始']
#
#
#
# Epoch  20	Mean Training Loss:769.8803584
#
# Topic_0: ['学名', '分布', '牠们', '台湾', '物种', '中国', '动物', '分佈']
# Topic_1: ['穆斯林', '伊斯兰教', '真主', '阿拉伯语', '古兰经', '基督教', '宗教', '伊斯兰']
# Topic_2: ['台湾', '主义', '运动', '中国', '革命', '民主', '中华', '人民']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '个人', '节目', '唱片']
# Topic_4: ['大学', '音乐', '中国', '学院', '台湾', '学校', '国立', '乐团']
# Topic_5: ['电影', '他们', '自己', '发现', '上映', '美国', '英语', '执导']
#
#
#
# Epoch  21	Mean Training Loss:769.3059239
#
# Topic_0: ['学名', '分布', '台湾', '中国', '牠们', '黑色', '物种', '动物']
# Topic_1: ['阿拉伯语', '伊斯兰教', '穆斯林', '真主', '古兰经', '基督教', '教会', '宗教']
# Topic_2: ['台湾', '主义', '中国', '革命', '组织', '中华', '运动', '人民']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '个人', '节目', '唱片']
# Topic_4: ['大学', '中国', '音乐', '学院', '学校', '台湾', '北京', '重点']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '英语', '开始']
#
#
#
# Epoch  22	Mean Training Loss:769.0547892
#
# Topic_0: ['学名', '分布', '台湾', '物种', '中国', '牠们', '黑色', '厘米']
# Topic_1: ['穆斯林', '伊斯兰教', '基督教', '阿拉伯语', '教会', '伊斯兰', '古兰经', '宗教']
# Topic_2: ['台湾', '中华', '主义', '中国', '革命', '运动', '组织', '国际']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '唱片', '个人']
# Topic_4: ['大学', '音乐', '学院', '中国', '学校', '重点', '学科', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '英语', '剧情']
#
#
#
# Epoch  23	Mean Training Loss:769.5352395
#
# Topic_0: ['学名', '分布', '台湾', '中国', '牠们', '物种', '地区', '分佈']
# Topic_1: ['阿拉伯语', '穆斯林', '阿拉伯', '伊斯兰教', '教会', '基督教', '古兰经', '穆罕默德']
# Topic_2: ['台湾', '主义', '中国', '社会主义', '运动', '社会', '组织', '国际']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '节目', '唱片', '演唱会']
# Topic_4: ['大学', '音乐', '中国', '学院', '学校', '台湾', '重点', '北京']
# Topic_5: ['电影', '他们', '自己', '发现', '上映', '美国', '英语', '剧情']
#
#
#
# Epoch  24	Mean Training Loss:767.2703001
#
# Topic_0: ['学名', '分布', '牠们', '台湾', '物种', '中国', '分佈', '黑色']
# Topic_1: ['穆斯林', '古兰经', '伊斯兰教', '阿拉伯', '伊斯兰', '教会', '阿拉伯语', '基督教']
# Topic_2: ['台湾', '中国', '主义', '运动', '中华', '革命', '国际', '组织']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '个人', '乐团', '参加']
# Topic_4: ['大学', '学院', '中国', '音乐', '学校', '工程', '国立', '国家']
# Topic_5: ['电影', '他们', '自己', '发现', '上映', '美国', '英语', '开始']
#
#
#
# Epoch  25	Mean Training Loss:766.9282179
#
# Topic_0: ['学名', '分布', '台湾', '物种', '中国', '牠们', '地区', '黑色']
# Topic_1: ['阿拉伯语', '古兰经', '穆斯林', '真主', '伊斯兰', '伊斯兰教', '阿拉伯', '宗教']
# Topic_2: ['台湾', '组织', '国际', '主义', '运动', '中国', '革命', '中华']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '唱片', '发行', '个人', '演唱会']
# Topic_4: ['大学', '学院', '音乐', '学校', '中国', '工程', '重点', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '英语', '剧情']
#
#
#
# Epoch  26	Mean Training Loss:766.4957500
#
# Topic_0: ['学名', '分布', '台湾', '牠们', '中国', '物种', '分佈', '动物']
# Topic_1: ['穆斯林', '伊斯兰教', '古兰经', '阿拉伯语', '真主', '伊斯兰', '基督教', '阿拉伯']
# Topic_2: ['台湾', '主义', '运动', '组织', '中国', '政府', '革命', '社会主义']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '个人', '节目', '唱片']
# Topic_4: ['大学', '音乐', '学院', '中国', '学校', '师范', '重点', '工程']
# Topic_5: ['电影', '他们', '自己', '发现', '美国', '上映', '英语', '剧情']
#
#
#
# Epoch  27	Mean Training Loss:765.4521719
#
# Topic_0: ['学名', '分布', '台湾', '中国', '物种', '动物', '牠们', '地区']
# Topic_1: ['阿拉伯语', '伊斯兰教', '穆斯林', '伊斯兰', '基督教', '古兰经', '真主', '阿拉伯']
# Topic_2: ['台湾', '运动', '中国', '组织', '人民', '政府', '主义', '中华']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '唱片', '个人', '节目']
# Topic_4: ['大学', '学院', '中国', '音乐', '学校', '工程', '重点', '学科']
# Topic_5: ['电影', '他们', '发现', '美国', '上映', '自己', '英语', '执导']
#
#
#
# Epoch  28	Mean Training Loss:767.3942933
#
# Topic_0: ['学名', '分布', '牠们', '台湾', '物种', '中国', '黑色', '动物']
# Topic_1: ['伊斯兰教', '穆斯林', '古兰经', '阿拉伯语', '伊斯兰', '阿拉伯', '基督教', '穆罕默德']
# Topic_2: ['台湾', '运动', '中国', '中华', '主义', '组织', '革命', '政府']
# Topic_3: ['台湾', '专辑', '音乐', '歌手', '发行', '个人', '节目', '唱片']
# Topic_4: ['大学', '中国', '学院', '音乐', '学校', '重点', '工程', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '英语']
#
#
#
# Epoch  29	Mean Training Loss:764.7822346
#
# Topic_0: ['学名', '分布', '物种', '中国', '牠们', '台湾', '黑色', '地区']
# Topic_1: ['穆斯林', '古兰经', '阿拉伯语', '伊斯兰教', '教会', '基督教', '阿拉伯', '宗教']
# Topic_2: ['台湾', '组织', '国际', '运动', '中华', '中国', '革命', '主义']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '唱片', '节目', '个人']
# Topic_4: ['大学', '学院', '中国', '学校', '音乐', '北京', '工程', '重点']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '开始', '英语']
#
#
#
# Epoch  30	Mean Training Loss:763.8276924
#
# Topic_0: ['学名', '分布', '物种', '台湾', '牠们', '中国', '特征', '黑色']
# Topic_1: ['伊斯兰教', '古兰经', '阿拉伯语', '穆斯林', '基督教', '教会', '阿拉伯', '世纪']
# Topic_2: ['台湾', '主义', '社会主义', '国际', '中国', '组织', '运动', '中华']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '个人', '唱片', '节目']
# Topic_4: ['大学', '学院', '中国', '学校', '音乐', '重点', '工程', '学科']
# Topic_5: ['电影', '他们', '发现', '美国', '上映', '自己', '执导', '英语']
#
#
#
# Epoch  31	Mean Training Loss:763.9562635
#
# Topic_0: ['学名', '分布', '物种', '台湾', '牠们', '中国', '黑色', '亚种']
# Topic_1: ['穆斯林', '伊斯兰教', '阿拉伯语', '古兰经', '教会', '伊斯兰', '阿拉伯', '基督教']
# Topic_2: ['台湾', '主义', '中华', '国际', '中国', '组织', '社会', '社会主义']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '个人', '唱片', '节目']
# Topic_4: ['大学', '学院', '音乐', '中国', '学校', '工程', '重点', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '英语', '开始']
#
#
#
# Epoch  32	Mean Training Loss:763.0698561
#
# Topic_0: ['学名', '分布', '台湾', '牠们', '物种', '中国', '黑色', '厘米']
# Topic_1: ['阿拉伯语', '伊斯兰教', '穆斯林', '古兰经', '宗教', '真主', '伊斯兰', '耶稣']
# Topic_2: ['台湾', '国际', '主义', '运动', '中华', '组织', '社会主义', '中国']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '节目', '唱片', '个人']
# Topic_4: ['大学', '学院', '中国', '学校', '工程', '音乐', '重点', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '上映', '美国', '开始', '英语']
#
#
#
# Epoch  33	Mean Training Loss:763.8139437
#
# Topic_0: ['学名', '分布', '台湾', '牠们', '物种', '中国', '地区', '黑色']
# Topic_1: ['穆斯林', '伊斯兰教', '阿拉伯语', '古兰经', '基督教', '教会', '伊斯兰', '真主']
# Topic_2: ['台湾', '运动', '国际', '主义', '中国', '社会主义', '独立', '中华']
# Topic_3: ['专辑', '台湾', '歌手', '音乐', '唱片', '发行', '个人', '节目']
# Topic_4: ['大学', '学院', '中国', '学校', '北京', '重点', '工程', '石油']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '英语']
#
#
#
# Epoch  34	Mean Training Loss:763.3990475
#
# Topic_0: ['学名', '分布', '台湾', '中国', '牠们', '黑色', '物种', '分佈']
# Topic_1: ['穆斯林', '伊斯兰教', '阿拉伯语', '伊斯兰', '古兰经', '基督教', '真主', '宗教']
# Topic_2: ['台湾', '中国', '组织', '运动', '主义', '国际', '中华', '人民']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '个人', '唱片', '节目']
# Topic_4: ['大学', '学院', '中国', '工程', '学校', '音乐', '重点', '学科']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '英语', '开始']
#
#
#
# Epoch  35	Mean Training Loss:761.3718450
#
# Topic_0: ['学名', '分布', '台湾', '物种', '牠们', '中国', '黑色', '地区']
# Topic_1: ['穆斯林', '阿拉伯语', '伊斯兰教', '伊斯兰', '古兰经', '基督教', '阿拉伯', '宗教']
# Topic_2: ['台湾', '国际', '运动', '主义', '组织', '中华', '人民', '中国']
# Topic_3: ['专辑', '台湾', '音乐', '歌手', '发行', '唱片', '个人', '第一']
# Topic_4: ['大学', '学院', '中国', '工程', '学校', '重点', '音乐', '北京']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '英语']
#
#
#
# Epoch  36	Mean Training Loss:762.2498315
#
# Topic_0: ['学名', '分布', '台湾', '中国', '物种', '分佈', '黑色', '牠们']
# Topic_1: ['阿拉伯语', '伊斯兰教', '真主', '穆斯林', '宗教', '伊斯兰', '不同', '基督教']
# Topic_2: ['台湾', '中国', '中华', '国际', '运动', '主义', '工人', '社会主义']
# Topic_3: ['专辑', '台湾', '歌手', '音乐', '发行', '个人', '节目', '唱片']
# Topic_4: ['大学', '学院', '中国', '学校', '北京', '重点', '工程', '音乐']
# Topic_5: ['电影', '他们', '发现', '美国', '自己', '上映', '开始', '英语']
#
#
#
# Epoch  37	Mean Training Loss:759.9635624
#
# Topic_0: ['学名', '分布', '物种', '台湾', '中国', '黑色', '牠们', '分佈']
# Topic_1: ['阿拉伯语', '伊斯兰教', '真主', '穆斯林', '古兰经', '伊斯兰', '先知', '穆罕默德']
# Topic_2: ['台湾', '国际', '主义', '中国', '中华', '工人', '民主', '组织']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '唱片', '个人', '节目']
# Topic_4: ['大学', '学院', '中国', '工程', '学校', '北京', '音乐', '重点']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '英语']
#
#
#
# Epoch  38	Mean Training Loss:760.1760043
#
# Topic_0: ['学名', '分布', '台湾', '物种', '中国', '厘米', '黑色', '地区']
# Topic_1: ['阿拉伯语', '伊斯兰教', '真主', '伊斯兰', '穆斯林', '古兰经', '基督教', '宗教']
# Topic_2: ['台湾', '国际', '运动', '中国', '中华', '主义', '组织', '工人']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '节目', '个人', '唱片']
# Topic_4: ['大学', '学院', '中国', '学校', '音乐', '北京', '工程', '重点']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '英语']
#
#
#
# Epoch  39	Mean Training Loss:761.7044549
#
# Topic_0: ['学名', '分布', '台湾', '物种', '地区', '牠们', '中国', '海拔']
# Topic_1: ['阿拉伯语', '穆斯林', '伊斯兰教', '古兰经', '伊斯兰', '真主', '基督教', '教会']
# Topic_2: ['台湾', '国际', '运动', '组织', '工人', '社会主义', '主义', '中华']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '个人', '节目', '唱片']
# Topic_4: ['大学', '学院', '学校', '中国', '学科', '音乐', '北京', '重点']
# Topic_5: ['电影', '他们', '发现', '自己', '美国', '上映', '开始', '所有']
#
#
#
# Epoch  40	Mean Training Loss:760.1506889
#
# Topic_0: ['学名', '分布', '台湾', '中国', '地区', '物种', '黑色', '特征']
# Topic_1: ['穆斯林', '阿拉伯语', '伊斯兰', '伊斯兰教', '古兰经', '圣经', '阿拉伯', '真主']
# Topic_2: ['台湾', '运动', '国际', '中华', '中国', '主义', '组织', '政府']
# Topic_3: ['专辑', '台湾', '音乐', '发行', '歌手', '节目', '唱片', '个人']
# Topic_4: ['大学', '学院', '中国', '学校', '北京', '重点', '师范', '工程']
# Topic_5: ['电影', '他们', '自己', '发现', '美国', '上映', '开始', '剧情']
#
#
#
# Early stopping at Epoch 40. Reverting to Epoch 37

# %%
print('Computing metrics for Chinese... Embeddings')
compute(tm_zh, train_dataset_zh, './output_task1_redo_zh_emb_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for Chinese... Embeddings
# 2 4 3 1 3 0
# f1_macro = 0.632074770278098
# f1_micro = 0.7209669462259497
# acc = 0.7209669462259497
# ars = 0.4976229846514392
# --------------------------------------------------

# %%
print('Computing metrics for Chinese... Embeddings, zh2en')
compute(tm_zh, train_dataset_en, './output_task1_redo_zh_emb_zh2en_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for Chinese... Embeddings, zh2en
# 2 4 3 1 4 0
# f1_macro = 0.6537581842360735
# f1_micro = 0.7064203567871049
# acc = 0.7064203567871049
# ars = 0.530294426266735
# --------------------------------------------------

# %%
print('Computing metrics for English... Embeddings, en2zh')
compute(tm_en, train_dataset_zh, './output_task1_redo_zh_emb_en2zh_{}'.format(MODEL_NAME))
# Out:
# Computing metrics for English... Embeddings, en2zh
# 2 4 0 1 3 5
# f1_macro = 0.5769282299039263
# f1_micro = 0.5800690675875678
# acc = 0.5800690675875678
# ars = 0.3326120011724781
# --------------------------------------------------
